# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Triplet_Hinge_Settings, Triplet_Log_Settings, Pair_Hinge_Settings
from features.models import GCNNSmall0, GCNNMedium0, GCNNMedium1, GCNNLarge0
from learn import get_feature_model, train_features, test_features
from datasets import load_cifar10
from classes.models import LinearClassifier0, LinearClassifier1, LinearClassifier2, LinearClassifier3, TwoLayerClassifier0, TwoLayerClassifier1
from learn import get_feature_model, get_classifier, train_features, train_classifier, test_model
# Out:
# /home/dqi/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/dqi/.conda/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data, samplers, pair_samplers, triplet_samplers = load_cifar10(augment=True)
# Out:
# CIFAR-10 loaded in 102 seconds

# %%
d=data; s=samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNMedium1, settings=Baseline_Settings,
                                num_features=10, data_format=[32, 32, 3],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gm1_cifar10_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gm1_cifar10_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.6, f_params=f_params)
    fs.save(sess, "./models/cifar10/b_gm1_cifar10_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.76857, train error 0.875
# 	step 200: train loss 2.77251, train error 0.82
# 	step 400: train loss 2.04258, train error 0.6
# 	step 600: train loss 1.79835, train error 0.555
# 	step 800: train loss 1.73519, train error 0.535
# 	step 1000: train loss 1.73335, train error 0.5025
# 	step 1200: train loss 1.53001, train error 0.4525
# 	step 1400: train loss 1.46878, train error 0.43
# 	step 1600: train loss 1.68893, train error 0.4925
# 	step 1800: train loss 1.32956, train error 0.3575
# 	step 2000: train loss 1.42388, train error 0.42
# 	step 2200: train loss 1.30732, train error 0.36
# 	step 2400: train loss 1.55082, train error 0.4775
# 	step 2600: train loss 1.42246, train error 0.4225
# 	step 2800: train loss 1.18997, train error 0.345
# 	step 3000: train loss 1.20319, train error 0.385
# 	step 3200: train loss 1.24967, train error 0.3775
# 	step 3400: train loss 1.40883, train error 0.4325
# 	step 3600: train loss 1.36058, train error 0.4
# 	step 3800: train loss 1.08591, train error 0.33
# 	step 4000: train loss 1.59415, train error 0.46
# 	step 4200: train loss 1.65606, train error 0.505
# 	step 4400: train loss 0.942156, train error 0.285
# 	step 4600: train loss 0.991162, train error 0.32
# 	step 4800: train loss 0.854563, train error 0.27
# 	step 5000: train loss 0.921702, train error 0.295
# 	step 5200: train loss 0.954043, train error 0.2825
# 	step 5400: train loss 0.947685, train error 0.3075
# 	step 5600: train loss 0.832914, train error 0.2725
# 	step 5800: train loss 0.921616, train error 0.28
# 	step 6000: train loss 0.87588, train error 0.2675
# 	step 6200: train loss 0.795521, train error 0.24
# 	step 6400: train loss 0.835167, train error 0.2725
# 	step 6600: train loss 0.700927, train error 0.2225
# 	step 6800: train loss 0.766414, train error 0.2425
# 	step 7000: train loss 0.721578, train error 0.225
# 	step 7200: train loss 0.614624, train error 0.1975
# 	step 7400: train loss 0.780203, train error 0.265
# 	step 7600: train loss 0.601984, train error 0.185
# 	step 7800: train loss 0.6856, train error 0.225
# 	step 8000: train loss 0.583824, train error 0.19
# 	step 8200: train loss 0.582947, train error 0.1875
# 	step 8400: train loss 0.695494, train error 0.24
# 	step 8600: train loss 0.553651, train error 0.1625
# 	step 8800: train loss 0.567185, train error 0.1625
# 	step 9000: train loss 0.624984, train error 0.1875
# 	step 9200: train loss 0.659787, train error 0.2025
# 	step 9400: train loss 0.484974, train error 0.1375
# 	step 9600: train loss 0.519291, train error 0.135
# 	step 9800: train loss 0.915683, train error 0.305
# 	step 10000: train loss 0.609628, train error 0.2
# 	step 10200: train loss 0.563425, train error 0.165
# 	step 10400: train loss 0.558333, train error 0.19
# 	step 10600: train loss 0.520334, train error 0.1475
# 	step 10800: train loss 0.563725, train error 0.175
# 	step 11000: train loss 0.522162, train error 0.16
# 	step 11200: train loss 0.453136, train error 0.115
# 	step 11400: train loss 0.552182, train error 0.1775
# 	step 11600: train loss 0.522686, train error 0.17
# 	step 11800: train loss 0.434915, train error 0.125
# 	step 12000: train loss 0.622342, train error 0.1775
# 	step 12200: train loss 0.438526, train error 0.125
# 	step 12400: train loss 0.447708, train error 0.1225
# 	step 12600: train loss 0.379279, train error 0.105
# 	step 12800: train loss 0.57762, train error 0.1925
# 	step 13000: train loss 0.523537, train error 0.155
# 	step 13200: train loss 0.461524, train error 0.145
# 	step 13400: train loss 0.464693, train error 0.135
# 	step 13600: train loss 0.496215, train error 0.15
# 	step 13800: train loss 0.559579, train error 0.17
# 	step 14000: train loss 0.410508, train error 0.1025
# 	step 14200: train loss 0.434129, train error 0.1375
# 	step 14400: train loss 0.384982, train error 0.105
# 	step 14600: train loss 0.454618, train error 0.1325
# 	step 14800: train loss 0.468906, train error 0.14
# 	step 15000: train loss 0.456636, train error 0.1525
# 	step 15200: train loss 0.47543, train error 0.1425
# 	step 15400: train loss 0.45609, train error 0.15
# 	step 15600: train loss 0.466281, train error 0.135
# 	step 15800: train loss 0.374813, train error 0.09
# 	step 16000: train loss 0.435749, train error 0.125
# 	step 16200: train loss 0.400296, train error 0.1125
# 	step 16400: train loss 0.381916, train error 0.1125
# 	step 16600: train loss 0.337972, train error 0.09
# 	step 16800: train loss 0.378697, train error 0.1175
# 	step 17000: train loss 0.474143, train error 0.13
# 	step 17200: train loss 0.464592, train error 0.1475
# 	step 17400: train loss 0.422922, train error 0.1325
# 	step 17600: train loss 0.345052, train error 0.0925
# 	step 17800: train loss 0.531187, train error 0.145
# 	step 18000: train loss 0.339924, train error 0.0875
# 	step 18200: train loss 0.306411, train error 0.0675
# 	step 18400: train loss 0.375406, train error 0.1075
# 	step 18600: train loss 0.399013, train error 0.1075
# 	step 18800: train loss 0.360513, train error 0.085
# 	step 19000: train loss 0.326983, train error 0.0675
# 	step 19200: train loss 0.323611, train error 0.08
# 	step 19400: train loss 0.350992, train error 0.1
# 	step 19600: train loss 0.304204, train error 0.0625
# 	step 19800: train loss 0.310848, train error 0.0625
# 	step 20000: train loss 0.406915, train error 0.115
# 	step 20200: train loss 0.326462, train error 0.08
# 	step 20400: train loss 0.354904, train error 0.08
# 	step 20600: train loss 0.308195, train error 0.075
# 	step 20800: train loss 0.307146, train error 0.0775
# 	step 21000: train loss 0.369103, train error 0.0975
# 	step 21200: train loss 0.32047, train error 0.0775
# 	step 21400: train loss 0.38105, train error 0.1
# 	step 21600: train loss 0.336162, train error 0.09
# 	step 21800: train loss 0.319125, train error 0.085
# 	step 22000: train loss 0.312334, train error 0.075
# 	step 22200: train loss 0.323279, train error 0.0825
# 	step 22400: train loss 0.366117, train error 0.0975
# 	step 22600: train loss 0.409634, train error 0.1125
# 	step 22800: train loss 0.332548, train error 0.075
# 	step 23000: train loss 0.323546, train error 0.0725
# 	step 23200: train loss 0.299606, train error 0.08
# 	step 23400: train loss 0.308424, train error 0.065
# 	step 23600: train loss 0.335161, train error 0.0825
# 	step 23800: train loss 0.279828, train error 0.0475
# 	step 24000: train loss 0.327034, train error 0.0825
# 	step 24200: train loss 0.253207, train error 0.045
# 	step 24400: train loss 0.346135, train error 0.095
# 	step 24600: train loss 0.316561, train error 0.08
# 	step 24800: train loss 0.327411, train error 0.075
# 	step 25000: train loss 0.261495, train error 0.045
# 	step 25200: train loss 0.297772, train error 0.075
# 	step 25400: train loss 0.284172, train error 0.07
# 	step 25600: train loss 0.294441, train error 0.0525
# 	step 25800: train loss 0.326578, train error 0.0775
# 	step 26000: train loss 0.279644, train error 0.06
# 	step 26200: train loss 0.300501, train error 0.065
# 	step 26400: train loss 0.252382, train error 0.04
# 	step 26600: train loss 0.303203, train error 0.0725
# 	step 26800: train loss 0.245949, train error 0.045
# 	step 27000: train loss 0.24782, train error 0.045
# 	step 27200: train loss 0.308025, train error 0.0625
# 	step 27400: train loss 0.322516, train error 0.0875
# 	step 27600: train loss 0.254229, train error 0.045
# 	step 27800: train loss 0.261017, train error 0.0575
# 	step 28000: train loss 0.265182, train error 0.045
# 	step 28200: train loss 0.255114, train error 0.045
# 	step 28400: train loss 0.258914, train error 0.055
# 	step 28600: train loss 0.258969, train error 0.045
# 	step 28800: train loss 0.28709, train error 0.0525
# 	step 29000: train loss 0.256964, train error 0.06
# 	step 29200: train loss 0.313772, train error 0.06
# 	step 29400: train loss 0.245207, train error 0.05
# 	step 29600: train loss 0.290617, train error 0.065
# 	step 29800: train loss 0.24078, train error 0.035
# 	step 30000: train loss 0.255878, train error 0.0475
# 	step 30200: train loss 0.2923, train error 0.0575
# 	step 30400: train loss 0.230726, train error 0.035
# 	step 30600: train loss 0.245058, train error 0.04
# 	step 30800: train loss 0.246526, train error 0.04
# 	step 31000: train loss 0.279849, train error 0.055
# 	step 31200: train loss 0.376226, train error 0.11
# 	step 31400: train loss 0.252767, train error 0.055
# 	step 31600: train loss 0.220258, train error 0.03
# 	step 31800: train loss 0.274683, train error 0.0525
# 	step 32000: train loss 0.24185, train error 0.0475
# 	step 32200: train loss 0.244915, train error 0.04
# 	step 32400: train loss 0.265951, train error 0.045
# 	step 32600: train loss 0.29803, train error 0.0525
# 	step 32800: train loss 0.248799, train error 0.04
# 	step 33000: train loss 0.231781, train error 0.045
# 	step 33200: train loss 0.386245, train error 0.0975
# 	step 33400: train loss 0.232613, train error 0.035
# 	step 33600: train loss 0.225425, train error 0.03
# 	step 33800: train loss 0.275689, train error 0.0625
# 	step 34000: train loss 0.236238, train error 0.0325
# 	step 34200: train loss 0.259687, train error 0.0475
# 	step 34400: train loss 0.241668, train error 0.035
# 	step 34600: train loss 0.228209, train error 0.035
# 	step 34800: train loss 0.25841, train error 0.0375
# 	step 35000: train loss 0.254703, train error 0.0425
# 	step 35200: train loss 0.202779, train error 0.03
# 	step 35400: train loss 0.304844, train error 0.0775
# 	step 35600: train loss 0.226183, train error 0.0375
# 	step 35800: train loss 0.243192, train error 0.0375
# 	step 36000: train loss 0.296299, train error 0.07
# 	step 36200: train loss 0.263966, train error 0.0325
# 	step 36400: train loss 0.237328, train error 0.045
# 	step 36600: train loss 0.227031, train error 0.035
# 	step 36800: train loss 0.22239, train error 0.0375
# 	step 37000: train loss 0.234784, train error 0.0425
# 	step 37200: train loss 0.209717, train error 0.0325
# 	step 37400: train loss 0.225978, train error 0.035
# 	step 37600: train loss 0.285934, train error 0.065
# 	step 37800: train loss 0.21878, train error 0.0225
# 	step 38000: train loss 0.23567, train error 0.03
# 	step 38200: train loss 0.218428, train error 0.035
# 	step 38400: train loss 0.227296, train error 0.04
# 	step 38600: train loss 0.245451, train error 0.045
# 	step 38800: train loss 0.297964, train error 0.06
# 	step 39000: train loss 0.221012, train error 0.0375
# 	step 39200: train loss 0.241354, train error 0.04
# 	step 39400: train loss 0.209773, train error 0.0325
# 	step 39600: train loss 0.25203, train error 0.0475
# 	step 39800: train loss 0.222353, train error 0.03
# end training features // time elapsed: 5639.0074 s
# validation set error: 0.1370 // time elapsed: 1.4596 s

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNLarge0, settings=Baseline_Settings,
                                num_features=10, data_format=[32, 32, 3],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gl0_cifar10_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gl0_cifar10_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.6, f_params=f_params)
    fs.save(sess, "./models/cifar10/b_gl0_cifar10_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.82248, train error 0.8975
# 	step 200: train loss 2.83957, train error 0.79
# 	step 400: train loss 2.12998, train error 0.6425
# 	step 600: train loss 2.37344, train error 0.6825
# 	step 800: train loss 1.63649, train error 0.475
# 	step 1000: train loss 1.7109, train error 0.4675
# 	step 1200: train loss 2.30851, train error 0.5825
# 	step 1400: train loss 1.50864, train error 0.42
# 	step 1600: train loss 1.36682, train error 0.3725
# 	step 1800: train loss 1.23136, train error 0.315
# 	step 2000: train loss 1.28463, train error 0.36
# 	step 2200: train loss 1.27327, train error 0.34
# 	step 2400: train loss 1.09421, train error 0.285
# 	step 2600: train loss 1.1607, train error 0.3075
# 	step 2800: train loss 1.42163, train error 0.395
# 	step 3000: train loss 1.04324, train error 0.2625
# 	step 3200: train loss 1.07217, train error 0.2975
# 	step 3400: train loss 0.935407, train error 0.25
# 	step 3600: train loss 1.00652, train error 0.2875
# 	step 3800: train loss 1.30079, train error 0.3725
# 	step 4000: train loss 0.923587, train error 0.28
# 	step 4200: train loss 0.983891, train error 0.315
# 	step 4400: train loss 0.87227, train error 0.265
# 	step 4600: train loss 0.846393, train error 0.265
# 	step 4800: train loss 0.890683, train error 0.2375
# 	step 5000: train loss 0.891158, train error 0.275
# 	step 5200: train loss 0.869378, train error 0.2725
# 	step 5400: train loss 0.693362, train error 0.2075
# 	step 5600: train loss 0.75238, train error 0.225
# 	step 5800: train loss 0.796403, train error 0.225
# 	step 6000: train loss 0.727395, train error 0.22
# 	step 6200: train loss 1.06696, train error 0.3225
# 	step 6400: train loss 0.524458, train error 0.15
# 	step 6600: train loss 0.678683, train error 0.205
# 	step 6800: train loss 0.735872, train error 0.24
# 	step 7000: train loss 0.615347, train error 0.1825
# 	step 7200: train loss 0.670526, train error 0.205
# 	step 7400: train loss 0.510211, train error 0.1475
# 	step 7600: train loss 0.588846, train error 0.1575
# 	step 7800: train loss 0.515472, train error 0.1525
# 	step 8000: train loss 0.539703, train error 0.16
# 	step 8200: train loss 0.472887, train error 0.11
# 	step 8400: train loss 0.532571, train error 0.1625
# 	step 8600: train loss 0.46846, train error 0.14
# 	step 8800: train loss 0.470688, train error 0.1325
# 	step 9000: train loss 0.64035, train error 0.21
# 	step 9200: train loss 0.550441, train error 0.155
# 	step 9400: train loss 0.498549, train error 0.1725
# 	step 9600: train loss 0.415563, train error 0.1225
# 	step 9800: train loss 0.446082, train error 0.1275
# 	step 10000: train loss 0.842869, train error 0.265
# 	step 10200: train loss 0.526594, train error 0.155
# 	step 10400: train loss 0.514952, train error 0.1425
# 	step 10600: train loss 0.371404, train error 0.0825
# 	step 10800: train loss 0.490838, train error 0.1325
# 	step 11000: train loss 0.373621, train error 0.105
# 	step 11200: train loss 0.440103, train error 0.125
# 	step 11400: train loss 0.57175, train error 0.185
# 	step 11600: train loss 0.403316, train error 0.105
# 	step 11800: train loss 0.409568, train error 0.1325
# 	step 12000: train loss 0.331844, train error 0.0725
# 	step 12200: train loss 0.315413, train error 0.0625
# 	step 12400: train loss 0.275981, train error 0.045
# 	step 12600: train loss 0.337445, train error 0.0725
# 	step 12800: train loss 0.336439, train error 0.0725
# 	step 13000: train loss 0.327501, train error 0.0775
# 	step 13200: train loss 0.315874, train error 0.0775
# 	step 13400: train loss 0.298471, train error 0.075
# 	step 13600: train loss 0.331114, train error 0.07
# 	step 13800: train loss 0.317375, train error 0.0775
# 	step 14000: train loss 0.319827, train error 0.0775
# 	step 14200: train loss 0.34115, train error 0.0875
# 	step 14400: train loss 0.33236, train error 0.095
# 	step 14600: train loss 0.376962, train error 0.1
# 	step 14800: train loss 0.304108, train error 0.07
# 	step 15000: train loss 0.286853, train error 0.0725
# 	step 15200: train loss 0.271916, train error 0.0625
# 	step 15400: train loss 0.360021, train error 0.085
# 	step 15600: train loss 0.32008, train error 0.0625
# 	step 15800: train loss 0.322398, train error 0.06
# 	step 16000: train loss 0.30398, train error 0.08
# 	step 16200: train loss 0.271276, train error 0.05
# 	step 16400: train loss 0.24812, train error 0.055
# 	step 16600: train loss 0.252684, train error 0.045
# 	step 16800: train loss 0.305883, train error 0.07
# 	step 17000: train loss 0.319017, train error 0.08
# 	step 17200: train loss 0.267875, train error 0.0525
# 	step 17400: train loss 0.256115, train error 0.0375
# 	step 17600: train loss 0.227711, train error 0.035
# 	step 17800: train loss 0.257143, train error 0.0375
# 	step 18000: train loss 0.243253, train error 0.045
# 	step 18200: train loss 0.266215, train error 0.055
# 	step 18400: train loss 0.229883, train error 0.02
# 	step 18600: train loss 0.252237, train error 0.0425
# 	step 18800: train loss 0.269915, train error 0.05
# 	step 19000: train loss 0.233292, train error 0.035
# 	step 19200: train loss 0.218102, train error 0.0225
# 	step 19400: train loss 0.245395, train error 0.0325
# 	step 19600: train loss 0.218237, train error 0.0275
# 	step 19800: train loss 0.235603, train error 0.03
# 	step 20000: train loss 0.23117, train error 0.03
# 	step 20200: train loss 0.22814, train error 0.03
# 	step 20400: train loss 0.196626, train error 0.02
# 	step 20600: train loss 0.197598, train error 0.0125
# 	step 20800: train loss 0.253999, train error 0.0325
# 	step 21000: train loss 0.234119, train error 0.035
# 	step 21200: train loss 0.193703, train error 0.015
# 	step 21400: train loss 0.229834, train error 0.02
# 	step 21600: train loss 0.217045, train error 0.03
# 	step 21800: train loss 0.260662, train error 0.0475
# 	step 22000: train loss 0.198056, train error 0.005
# 	step 22200: train loss 0.209025, train error 0.02
# 	step 22400: train loss 0.231821, train error 0.0325
# 	step 22600: train loss 0.192681, train error 0.0125
# 	step 22800: train loss 0.224068, train error 0.0225
# 	step 23000: train loss 0.211068, train error 0.02
# 	step 23200: train loss 0.2188, train error 0.0325
# 	step 23400: train loss 0.202393, train error 0.0175
# 	step 23600: train loss 0.20367, train error 0.015
# 	step 23800: train loss 0.236304, train error 0.035
# 	step 24000: train loss 0.233059, train error 0.02
# 	step 24200: train loss 0.20645, train error 0.015
# 	step 24400: train loss 0.199226, train error 0.015
# 	step 24600: train loss 0.188618, train error 0.0125
# 	step 24800: train loss 0.212144, train error 0.0225
# 	step 25000: train loss 0.214509, train error 0.02
# 	step 25200: train loss 0.200374, train error 0.0175
# 	step 25400: train loss 0.268788, train error 0.0425
# 	step 25600: train loss 0.190963, train error 0.00999999
# 	step 25800: train loss 0.195914, train error 0.0125
# 	step 26000: train loss 0.202922, train error 0.0175
# 	step 26200: train loss 0.186871, train error 0.00749999
# 	step 26400: train loss 0.300088, train error 0.065
# 	step 26600: train loss 0.268279, train error 0.0375
# 	step 26800: train loss 0.217692, train error 0.0175
# 	step 27000: train loss 0.219546, train error 0.0275
# 	step 27200: train loss 0.186302, train error 0.00749999
# 	step 27400: train loss 0.198724, train error 0.0175
# 	step 27600: train loss 0.193604, train error 0.005
# 	step 27800: train loss 0.210937, train error 0.0225
# 	step 28000: train loss 0.173239, train error 0
# 	step 28200: train loss 0.201567, train error 0.0175
# 	step 28400: train loss 0.182274, train error 0.005
# 	step 28600: train loss 0.231766, train error 0.02
# 	step 28800: train loss 0.194232, train error 0.0125
# 	step 29000: train loss 0.189317, train error 0.0125
# 	step 29200: train loss 0.173326, train error 0.00749999
# 	step 29400: train loss 0.182814, train error 0.00999999
# 	step 29600: train loss 0.173349, train error 0
# 	step 29800: train loss 0.211063, train error 0.0175
# 	step 30000: train loss 0.174615, train error 0.005
# 	step 30200: train loss 0.175263, train error 0
# 	step 30400: train loss 0.185177, train error 0.00749999
# 	step 30600: train loss 0.214098, train error 0.015
# 	step 30800: train loss 0.190296, train error 0.0125
# 	step 31000: train loss 0.177433, train error 0.00999999
# 	step 31200: train loss 0.186646, train error 0.00999999
# 	step 31400: train loss 0.268205, train error 0.0375
# 	step 31600: train loss 0.197355, train error 0.0125
# 	step 31800: train loss 0.177691, train error 0.005
# 	step 32000: train loss 0.168487, train error 0.0025
# 	step 32200: train loss 0.178031, train error 0
# 	step 32400: train loss 0.188809, train error 0.00749999
# 	step 32600: train loss 0.17494, train error 0.0025
# 	step 32800: train loss 0.189121, train error 0.00999999
# 	step 33000: train loss 0.190087, train error 0.00999999
# 	step 33200: train loss 0.176499, train error 0.00749999
# 	step 33400: train loss 0.174115, train error 0.0025
# 	step 33600: train loss 0.180482, train error 0.005
# 	step 33800: train loss 0.169135, train error 0.005
# 	step 34000: train loss 0.198274, train error 0.00999999
# 	step 34200: train loss 0.199053, train error 0.00999999
# 	step 34400: train loss 0.170178, train error 0.005
# 	step 34600: train loss 0.170376, train error 0.0025
# 	step 34800: train loss 0.175945, train error 0.00749999
# 	step 35000: train loss 0.17693, train error 0.005
# 	step 35200: train loss 0.178518, train error 0.00749999
# 	step 35400: train loss 0.169414, train error 0.0025
# 	step 35600: train loss 0.187238, train error 0.00749999
# 	step 35800: train loss 0.187442, train error 0.00749999
# 	step 36000: train loss 0.181604, train error 0.00999999
# 	step 36200: train loss 0.186905, train error 0.0025
# 	step 36400: train loss 0.173388, train error 0.005
# 	step 36600: train loss 0.185089, train error 0.00999999
# 	step 36800: train loss 0.174693, train error 0.00749999
# 	step 37000: train loss 0.171181, train error 0.0025
# 	step 37200: train loss 0.193865, train error 0.0125
# 	step 37400: train loss 0.174216, train error 0.0025
# 	step 37600: train loss 0.178261, train error 0.005
# 	step 37800: train loss 0.171467, train error 0.0025
# 	step 38000: train loss 0.172848, train error 0
# 	step 38200: train loss 0.189925, train error 0.00749999
# 	step 38400: train loss 0.166797, train error 0
# 	step 38600: train loss 0.168643, train error 0
# 	step 38800: train loss 0.172436, train error 0.0025
# 	step 39000: train loss 0.174346, train error 0
# 	step 39200: train loss 0.186575, train error 0.0025
# 	step 39400: train loss 0.172815, train error 0.0025
# 	step 39600: train loss 0.190976, train error 0.00749999
# 	step 39800: train loss 0.245287, train error 0.035
# end training features // time elapsed: 7143.7783 s
# validation set error: 0.1348 // time elapsed: 1.2793 s
