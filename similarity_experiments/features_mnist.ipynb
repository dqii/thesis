# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Triplet_Hinge_Settings, Pair_Hinge_Settings, Triplet_Distance_Settings
from features.models import CNNSmall0, CNNSmall1, CNNSmall2, CNNMedium0, CNNMedium1, CNNLarge0, CNNLarge1
from features.models import STNCNNSmall0, STNCNNSmall1, STNCNNSmall2, STNCNNMedium0, STNCNNMedium1
from classes.models import LinearClassifier0
from learn import get_feature_model, train_features, test_features
from datasets import load_mnist
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data, samplers, pair_samplers, triplet_samplers = load_mnist(augment=True)
# Out:
# MNIST loaded in 18 seconds

# %% [markdown]
# # Distance

# %%
d = data; s=triplet_samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Distance_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs1_mnist_10"))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/d_cs1_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04222, train error 0.39, valid loss 1.02849, valid error 0.3025
# 	step 200: train loss 0.958559, train error 0.287143, valid loss 0.97445, valid error 0.2525
# 	step 400: train loss 0.39094, train error 0.122857, valid loss 0.339345, valid error 0.0725
# 	step 600: train loss 0.160371, train error 0.0471429, valid loss 0.120453, valid error 0.0275
# 	step 800: train loss 0.121725, train error 0.0285714, valid loss 0.110802, valid error 0.0225
# 	step 1000: train loss 0.103161, train error 0.02, valid loss 0.0834649, valid error 0.00999999
# 	step 1200: train loss 0.115615, train error 0.0214286, valid loss 0.101826, valid error 0.0175
# 	step 1400: train loss 0.0757666, train error 0.0142857, valid loss 0.0886897, valid error 0.0225
# 	step 1600: train loss 0.0959694, train error 0.0271429, valid loss 0.0647495, valid error 0.0175
# 	step 1800: train loss 0.0601335, train error 0.0128571, valid loss 0.064732, valid error 0.0125
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Distance_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs0_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs0_mnist_10_"))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/d_cs0_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05116, train error 0.363333, valid loss 1.05121, valid error 0.3575
# 	step 200: train loss 0.705645, train error 0.21, valid loss 0.762617, valid error 0.1775
# 	step 400: train loss 0.279488, train error 0.0866666, valid loss 0.267694, valid error 0.06
# 	step 600: train loss 0.220285, train error 0.06, valid loss 0.192911, valid error 0.045
# 	step 800: train loss 0.174439, train error 0.06, valid loss 0.155861, valid error 0.0425
# 	step 1000: train loss 0.133993, train error 0.0366667, valid loss 0.16163, valid error 0.0425
# 	step 1200: train loss 0.144794, train error 0.0366667, valid loss 0.147719, valid error 0.035
# 	step 1400: train loss 0.096313, train error 0.0166667, valid loss 0.116621, valid error 0.02
# 	step 1600: train loss 0.0986133, train error 0.02, valid loss 0.0904366, valid error 0.015
# 	step 1800: train loss 0.112216, train error 0.0266666, valid loss 0.13155, valid error 0.025
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Distance_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs1_mnist_10"))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/d_cs1_mnist_10.ckpt")
    test_features(sess=sess, feature_model=f, samplers=s, f_params=f_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/d_cs1_mnist_10.ckpt
# test set error: 0.0024 // time elapsed: 12.0783 s

# %% [markdown]
# # Triplets

# %% [markdown]
# # 40

# %%
d = data; s=triplet_samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=40, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_40")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_40"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/mnist/f_cs1_mnist_40.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05548, train error 0.548571, valid loss 1.02861, valid error 0.4725
# 	step 200: train loss 0.846091, train error 0.332857, valid loss 0.900277, valid error 0.3525
# 	step 400: train loss 0.319658, train error 0.114286, valid loss 0.380887, valid error 0.1325
# 	step 600: train loss 0.156885, train error 0.0471429, valid loss 0.173079, valid error 0.06
# 	step 800: train loss 0.115941, train error 0.0285714, valid loss 0.121316, valid error 0.0275
# 	step 1000: train loss 0.150773, train error 0.0471429, valid loss 0.148134, valid error 0.0425
# 	step 1200: train loss 0.0952196, train error 0.0214286, valid loss 0.0764429, valid error 0.0125
# 	step 1400: train loss 0.0937767, train error 0.0242857, valid loss 0.0978416, valid error 0.0275
# 	step 1600: train loss 0.0878043, train error 0.0242857, valid loss 0.106952, valid error 0.0325
# ...

# %% [markdown]
# # 20

# %%
d = data; s=triplet_samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_cs0_mnist_20")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_20"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/mnist/f_cs0_mnist_20.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.06475, train error 0.556667, valid loss 1.01949, valid error 0.445
# 	step 200: train loss 0.788688, train error 0.356667, valid loss 0.792494, valid error 0.245
# 	step 400: train loss 0.340319, train error 0.116667, valid loss 0.330166, valid error 0.1075
# 	step 600: train loss 0.198927, train error 0.0666667, valid loss 0.197814, valid error 0.045
# 	step 800: train loss 0.117971, train error 0.02, valid loss 0.14124, valid error 0.04
# 	step 1000: train loss 0.141004, train error 0.05, valid loss 0.153716, valid error 0.04
# 	step 1200: train loss 0.111937, train error 0.0266666, valid loss 0.103041, valid error 0.02
# 	step 1400: train loss 0.105262, train error 0.0233333, valid loss 0.139463, valid error 0.0325
# 	step 1600: train loss 0.116994, train error 0.03, valid loss 0.0963078, valid error 0.0225
# 	step 1800: train loss 0.107443, train error 0.03, valid loss 0.102265, valid error 0.0225
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_20_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_20_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/mnist/f_cs0_mnist_20_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 0.98155, train error 0.486667, valid loss 1.01004, valid error 0.4875
# 	step 200: train loss 0.535269, train error 0.166667, valid loss 0.761821, valid error 0.23
# 	step 400: train loss 0.256365, train error 0.0833333, valid loss 0.405497, valid error 0.1325
# 	step 600: train loss 0.18402, train error 0.0666667, valid loss 0.204183, valid error 0.0675
# 	step 800: train loss 0.160654, train error 0.0466667, valid loss 0.152107, valid error 0.05
# 	step 1000: train loss 0.158234, train error 0.0433334, valid loss 0.120137, valid error 0.035
# 	step 1200: train loss 0.134638, train error 0.04, valid loss 0.133099, valid error 0.0425
# 	step 1400: train loss 0.100723, train error 0.0266666, valid loss 0.0833851, valid error 0.0225
# 	step 1600: train loss 0.111237, train error 0.0266666, valid loss 0.115511, valid error 0.035
# 	step 1800: train loss 0.0950505, train error 0.0266666, valid loss 0.0882225, valid error 0.0225
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_20")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_20"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/mnist/f_cs1_mnist_20.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05199, train error 0.504286, valid loss 1.04481, valid error 0.45
# 	step 200: train loss 0.644584, train error 0.268571, valid loss 0.701827, valid error 0.2425
# 	step 400: train loss 0.293427, train error 0.11, valid loss 0.295337, valid error 0.095
# 	step 600: train loss 0.140844, train error 0.0385714, valid loss 0.136382, valid error 0.03
# 	step 800: train loss 0.148998, train error 0.0471429, valid loss 0.123495, valid error 0.035
# 	step 1000: train loss 0.103897, train error 0.03, valid loss 0.1047, valid error 0.0225
# 	step 1200: train loss 0.101503, train error 0.0285714, valid loss 0.0758071, valid error 0.0175
# 	step 1400: train loss 0.0777588, train error 0.0214286, valid loss 0.0800874, valid error 0.0225
# 	step 1600: train loss 0.0858718, train error 0.02, valid loss 0.083598, valid error 0.025
# 	step 1800: train loss 0.0520822, train error 0.0057143, valid loss 0.0583955, valid error 0.015
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_20_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_20_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.7, f_params=f_params)
    fs.save(sess, "./models/mnist/f_cs1_mnist_20_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.03532, train error 0.533333, valid loss 1.02164, valid error 0.4275
# 	step 200: train loss 1.0512, train error 0.386667, valid loss 0.968679, valid error 0.35
# 	step 400: train loss 0.451147, train error 0.143333, valid loss 0.459872, valid error 0.1325
# 	step 600: train loss 0.212153, train error 0.0633333, valid loss 0.288154, valid error 0.1025
# 	step 800: train loss 0.218908, train error 0.0566667, valid loss 0.244305, valid error 0.0725
# 	step 1000: train loss 0.170236, train error 0.0466667, valid loss 0.205719, valid error 0.0625
# 	step 1200: train loss 0.194948, train error 0.0666667, valid loss 0.178453, valid error 0.06
# 	step 1400: train loss 0.158455, train error 0.0433334, valid loss 0.157719, valid error 0.0425
# 	step 1600: train loss 0.12391, train error 0.03, valid loss 0.140491, valid error 0.0375
# 	step 1800: train loss 0.101523, train error 0.0333334, valid loss 0.108213, valid error 0.025
# ...

# %% [markdown]
# # 10

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_cs0_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f_cs0_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04497, train error 0.47, valid loss 1.04803, valid error 0.488571
# 	step 200: train loss 0.841612, train error 0.381429, valid loss 0.835202, valid error 0.271429
# 	step 400: train loss 0.288489, train error 0.0942857, valid loss 0.321036, valid error 0.0914286
# 	step 600: train loss 0.180574, train error 0.05, valid loss 0.192379, valid error 0.05
# 	step 800: train loss 0.15703, train error 0.05, valid loss 0.14244, valid error 0.0428572
# 	step 1000: train loss 0.130032, train error 0.04, valid loss 0.115966, valid error 0.03
# 	step 1200: train loss 0.108508, train error 0.0214286, valid loss 0.120425, valid error 0.0357143
# 	step 1400: train loss 0.111035, train error 0.0314286, valid loss 0.0848677, valid error 0.0157143
# 	step 1600: train loss 0.11296, train error 0.0285714, valid loss 0.0924059, valid error 0.0228571
# 	step 1800: train loss 0.0843992, train error 0.0171428, valid loss 0.0731615, valid error 0.0157143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f_cs0_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05303, train error 0.511429, valid loss 1.04941, valid error 0.482857
# 	step 200: train loss 0.743915, train error 0.318571, valid loss 0.721793, valid error 0.248571
# 	step 400: train loss 0.242615, train error 0.0728571, valid loss 0.215214, valid error 0.0514286
# 	step 600: train loss 0.14823, train error 0.0442857, valid loss 0.169036, valid error 0.0485714
# 	step 800: train loss 0.139159, train error 0.04, valid loss 0.138801, valid error 0.0385714
# 	step 1000: train loss 0.115236, train error 0.0314286, valid loss 0.109202, valid error 0.03
# 	step 1200: train loss 0.110137, train error 0.0271429, valid loss 0.0935119, valid error 0.0171428
# 	step 1400: train loss 0.093231, train error 0.0228571, valid loss 0.0867327, valid error 0.0257143
# 	step 1600: train loss 0.0652605, train error 0.0128571, valid loss 0.0715822, valid error 0.02
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f_cs1_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04847, train error 0.455714, valid loss 1.05219, valid error 0.535714
# 	step 200: train loss 0.732563, train error 0.321429, valid loss 0.933624, valid error 0.378571
# 	step 400: train loss 0.298505, train error 0.1, valid loss 0.310512, valid error 0.104286
# 	step 600: train loss 0.177286, train error 0.0571429, valid loss 0.150147, valid error 0.0414286
# 	step 800: train loss 0.138376, train error 0.04, valid loss 0.141296, valid error 0.04
# 	step 1000: train loss 0.0931864, train error 0.0242857, valid loss 0.104868, valid error 0.0271429
# 	step 1200: train loss 0.0916692, train error 0.0242857, valid loss 0.0812666, valid error 0.0171428
# 	step 1400: train loss 0.0923253, train error 0.0242857, valid loss 0.0747765, valid error 0.0142857
# 	step 1600: train loss 0.0752738, train error 0.0185714, valid loss 0.0711238, valid error 0.0142857
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_cs1_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f_cs1_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05156, train error 0.497143, valid loss 1.05127, valid error 0.502857
# 	step 200: train loss 0.882677, train error 0.394286, valid loss 0.882461, valid error 0.331429
# 	step 400: train loss 0.331864, train error 0.121429, valid loss 0.324448, valid error 0.1
# 	step 600: train loss 0.160765, train error 0.0528572, valid loss 0.17189, valid error 0.0471429
# 	step 800: train loss 0.126988, train error 0.0357143, valid loss 0.156523, valid error 0.0471429
# 	step 1000: train loss 0.116143, train error 0.0285714, valid loss 0.131141, valid error 0.0314286
# 	step 1200: train loss 0.135508, train error 0.04, valid loss 0.109947, valid error 0.0242857
# 	step 1400: train loss 0.107783, train error 0.0271429, valid loss 0.0960651, valid error 0.02
# 	step 1600: train loss 0.089366, train error 0.0228571, valid loss 0.103511, valid error 0.0285714
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=STNCNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.01, f_reg=0.001, f_scope="f_scs0_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_scs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f_scs0_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.05271, train error 0.532857, valid loss 1.05102, valid error 0.482857
# 	step 200: train loss 0.947372, train error 0.438571, valid loss 1.01, valid error 0.447143
# 	step 400: train loss 0.798864, train error 0.371429, valid loss 0.797853, valid error 0.322857
# 	step 600: train loss 0.514717, train error 0.201429, valid loss 0.639801, valid error 0.252857
# 	step 800: train loss 0.444218, train error 0.167143, valid loss 0.597335, valid error 0.247143
# 	step 1000: train loss 0.435267, train error 0.181429, valid loss 0.543734, valid error 0.221429
# 	step 1200: train loss 0.473514, train error 0.188571, valid loss 0.524125, valid error 0.201429
# 	step 1400: train loss 0.409059, train error 0.157143, valid loss 0.520898, valid error 0.217143
# 	step 1600: train loss 0.393088, train error 0.154286, valid loss 0.476934, valid error 0.187143
# ...

# %% [markdown]
# # Pairs

# %%
d = data; s = pair_samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Pair_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f2_cs0_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f2_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f2_cs0_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.51321, train error 0.849524, valid loss 2.66321, valid error 0.904762
# 	step 200: train loss 3.80124, train error 0.868571, valid loss 3.4275, valid error 0.891429
# 	step 400: train loss 1.63189, train error 0.687619, valid loss 1.34986, valid error 0.709524
# 	step 600: train loss 0.691312, train error 0.297143, valid loss 0.917866, valid error 0.390476
# 	step 800: train loss 0.563876, train error 0.231429, valid loss 0.776581, valid error 0.310476
# 	step 1000: train loss 0.558888, train error 0.226667, valid loss 0.732248, valid error 0.278095
# 	step 1200: train loss 0.530192, train error 0.189524, valid loss 0.723152, valid error 0.27619
# 	step 1400: train loss 0.514924, train error 0.211429, valid loss 0.667554, valid error 0.26
# 	step 1600: train loss 0.475547, train error 0.18, valid loss 0.639152, valid error 0.234286
# 	step 1800: train loss 0.440244, train error 0.15619, valid loss 0.643318, valid error 0.24
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Pair_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f2_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f2_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f2_cs1_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.57684, train error 0.844762, valid loss 1.64674, valid error 0.891429
# 	step 200: train loss 6.86277, train error 0.86, valid loss 5.87787, valid error 0.905714
# 	step 400: train loss 2.57202, train error 0.777143, valid loss 1.35332, valid error 0.768571
# 	step 600: train loss 0.688382, train error 0.32381, valid loss 0.984254, valid error 0.460952
# 	step 800: train loss 0.614836, train error 0.254286, valid loss 0.844723, valid error 0.334286
# 	step 1000: train loss 0.54159, train error 0.213333, valid loss 0.822424, valid error 0.310476
# 	step 1200: train loss 0.522236, train error 0.186667, valid loss 0.749685, valid error 0.258095
# 	step 1400: train loss 0.491466, train error 0.173333, valid loss 0.700273, valid error 0.255238
# 	step 1600: train loss 0.43655, train error 0.165714, valid loss 0.630302, valid error 0.202857
# 	step 1800: train loss 0.463755, train error 0.164762, valid loss 0.691421, valid error 0.232381
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Pair_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f2_cs1_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f2_cs1_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f2_cs1_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.6137, train error 0.854286, valid loss 1.71767, valid error 0.914286
# 	step 200: train loss 3.62855, train error 0.822857, valid loss 3.14163, valid error 0.885714
# 	step 400: train loss 1.2167, train error 0.488571, valid loss 1.09265, valid error 0.517143
# 	step 600: train loss 0.632124, train error 0.302857, valid loss 0.854656, valid error 0.4
# 	step 800: train loss 0.566248, train error 0.268571, valid loss 0.805897, valid error 0.325714
# 	step 1000: train loss 0.532291, train error 0.237143, valid loss 0.752063, valid error 0.36
# 	step 1200: train loss 0.521792, train error 0.22, valid loss 0.680425, valid error 0.282857
# 	step 1400: train loss 0.513286, train error 0.202857, valid loss 0.713955, valid error 0.282857
# 	step 1600: train loss 0.391223, train error 0.142857, valid loss 0.681999, valid error 0.265714
# 	step 1800: train loss 0.469813, train error 0.165714, valid loss 0.616311, valid error 0.217143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=STNCNNSmall0, settings=Pair_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f2_scs0_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f2_scs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/f2_scs0_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.99404, train error 0.825714, valid loss 2.19862, valid error 0.914286
# 	step 200: train loss 1.08387, train error 0.692857, valid loss 1.10163, valid error 0.747143
# 	step 400: train loss 1.93402, train error 0.818571, valid loss 1.6498, valid error 0.88
# 	step 600: train loss 0.632491, train error 0.345714, valid loss 0.992246, valid error 0.615
# 	step 800: train loss 0.613632, train error 0.31, valid loss 0.957621, valid error 0.475714
# 	step 1000: train loss 0.56225, train error 0.327143, valid loss 0.865503, valid error 0.51
# 	step 1200: train loss 0.540142, train error 0.338571, valid loss 0.863901, valid error 0.505714
# 	step 1400: train loss 0.53701, train error 0.361429, valid loss 0.800133, valid error 0.55
# 	step 1600: train loss 0.499968, train error 0.31, valid loss 0.758703, valid error 0.557143
# 	step 1800: train loss 0.4844, train error 0.322857, valid loss 0.840314, valid error 0.527143
# ...

# %% [markdown]
# # Baseline

# %%
d = data; s=samplers

# %%
# validation 0.0113
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="b_cs0_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=30000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/b_cs0_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.56884, train error 0.9, valid loss 2.45019, valid error 0.911429
# 	step 200: train loss 2.02008, train error 0.618571, valid loss 2.56165, valid error 0.841429
# 	step 400: train loss 0.817405, train error 0.242857, valid loss 0.886308, valid error 0.241429
# 	step 600: train loss 0.350917, train error 0.0957143, valid loss 0.249011, valid error 0.0457143
# 	step 800: train loss 0.236259, train error 0.05, valid loss 0.147267, valid error 0.02
# 	step 1000: train loss 0.246576, train error 0.0628572, valid loss 0.135996, valid error 0.0157143
# 	step 1200: train loss 0.182762, train error 0.0471429, valid loss 0.145328, valid error 0.0342857
# 	step 1400: train loss 0.178154, train error 0.0371429, valid loss 0.16999, valid error 0.04
# 	step 1600: train loss 0.116491, train error 0.0228571, valid loss 0.105211, valid error 0.0228571
# 	step 1800: train loss 0.135158, train error 0.0285714, valid loss 0.0943427, valid error 0.00999999
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.02, f_reg=0.001, f_scope="b_cs0_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=60000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/b_cs0_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.35197, train error 0.915714, valid loss 2.40342, valid error 0.91
# 	step 200: train loss 2.70064, train error 0.677143, valid loss 3.48466, valid error 0.912857
# 	step 400: train loss 1.02729, train error 0.312857, valid loss 1.03847, valid error 0.281429
# 	step 600: train loss 0.492685, train error 0.14, valid loss 0.369908, valid error 0.0828571
# 	step 800: train loss 0.394131, train error 0.0985714, valid loss 0.250155, valid error 0.04
# 	step 1000: train loss 0.359153, train error 0.0857143, valid loss 0.235409, valid error 0.0428572
# 	step 1200: train loss 0.283091, train error 0.0742857, valid loss 0.22105, valid error 0.0414286
# 	step 1400: train loss 0.281513, train error 0.0728571, valid loss 0.169285, valid error 0.04
# 	step 1600: train loss 0.23552, train error 0.0542857, valid loss 0.163647, valid error 0.0271429
# 	step 1800: train loss 0.243416, train error 0.07, valid loss 0.141002, valid error 0.0214286
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.03, f_reg=0.001, f_scope="b_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=60000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/b_cs1_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.5695, train error 0.932857, valid loss 2.45655, valid error 0.918571
# 	step 200: train loss 2.98881, train error 0.674286, valid loss 3.83478, valid error 0.907143
# 	step 400: train loss 1.05865, train error 0.33, valid loss 1.18448, valid error 0.362857
# 	step 600: train loss 0.481246, train error 0.127143, valid loss 0.416949, valid error 0.104286
# 	step 800: train loss 0.265919, train error 0.0657143, valid loss 0.210412, valid error 0.0342857
# 	step 1000: train loss 0.210517, train error 0.0485714, valid loss 0.148527, valid error 0.0271429
# 	step 1200: train loss 0.176155, train error 0.0428572, valid loss 0.166246, valid error 0.0371429
# 	step 1400: train loss 0.230327, train error 0.0557143, valid loss 0.132543, valid error 0.04
# 	step 1600: train loss 0.161658, train error 0.04, valid loss 0.14529, valid error 0.0357143
# 	step 1800: train loss 0.151555, train error 0.0242857, valid loss 0.145131, valid error 0.0342857
# ...

# %% [markdown]
# # Small Baseline

# %%
d = data; s=samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_cs0_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=30000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/sb_cs0_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.29814, train error 0.932857, valid loss 2.4073, valid error 0.907143
# 	step 200: train loss 1.77461, train error 0.59, valid loss 2.1158, valid error 0.751429
# 	step 400: train loss 0.556332, train error 0.158571, valid loss 0.585432, valid error 0.14
# 	step 600: train loss 0.357411, train error 0.0914286, valid loss 0.236465, valid error 0.0471429
# 	step 800: train loss 0.285209, train error 0.0785714, valid loss 0.213546, valid error 0.07
# 	step 1000: train loss 0.213418, train error 0.04, valid loss 0.170318, valid error 0.0328571
# 	step 1200: train loss 0.203421, train error 0.0485714, valid loss 0.142286, valid error 0.0228571
# 	step 1400: train loss 0.172223, train error 0.0357143, valid loss 0.142736, valid error 0.03
# 	step 1600: train loss 0.198437, train error 0.0485714, valid loss 0.149473, valid error 0.0385714
# 	step 1800: train loss 0.130831, train error 0.0314286, valid loss 0.117554, valid error 0.03
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="sb_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=30000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/sb_cs1_mnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.37093, train error 0.932857, valid loss 2.39071, valid error 0.898571
# 	step 200: train loss 4.0647, train error 0.65, valid loss 5.66998, valid error 0.924286
# 	step 400: train loss 2.40723, train error 0.591429, valid loss 2.83033, valid error 0.758571
# 	step 600: train loss 0.606426, train error 0.177143, valid loss 0.427295, valid error 0.1
# 	step 800: train loss 0.255551, train error 0.06, valid loss 0.170908, valid error 0.0357143
# 	step 1000: train loss 0.181054, train error 0.0328571, valid loss 0.149407, valid error 0.0342857
# 	step 1200: train loss 0.148275, train error 0.0285714, valid loss 0.123361, valid error 0.0214286
# 	step 1400: train loss 0.153436, train error 0.0357143, valid loss 0.14935, valid error 0.04
# 	step 1600: train loss 0.180215, train error 0.0485714, valid loss 0.110714, valid error 0.02
# 	step 1800: train loss 0.128214, train error 0.03, valid loss 0.113109, valid error 0.0228571
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="sb_cs1_mnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs1_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=30000, keep_prob=0.7, f_params=f_params)
    fs.save(sess, "./models/sb_cs1_mnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.48222, train error 0.93, valid loss 2.4674, valid error 0.904286
# 	step 200: train loss 4.00096, train error 0.664286, valid loss 5.25572, valid error 0.902857
# 	step 400: train loss 1.56861, train error 0.504286, valid loss 1.82827, valid error 0.575714
# 	step 600: train loss 0.512643, train error 0.14, valid loss 0.420821, valid error 0.0985714
# 	step 800: train loss 0.336862, train error 0.0842857, valid loss 0.265649, valid error 0.0628572
# 	step 1000: train loss 0.313291, train error 0.09, valid loss 0.181399, valid error 0.0357143
# 	step 1200: train loss 0.255521, train error 0.0642857, valid loss 0.216347, valid error 0.0528572
# 	step 1400: train loss 0.210553, train error 0.0542857, valid loss 0.15104, valid error 0.03
# 	step 1600: train loss 0.204317, train error 0.0457143, valid loss 0.15499, valid error 0.0385714
# 	step 1800: train loss 0.181328, train error 0.0442857, valid loss 0.152347, valid error 0.0371429
# ...

# %% [markdown]
# # Test results

# %%
d = data; s=triplet_samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs1_mnist_10.ckpt")
    test_features(sess=sess, feature_model=f, samplers=s, f_params=f_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs1_mnist_10.ckpt
# test set error: 0.0022 // time elapsed: 24.1370 s

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_20")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_20"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_20.ckpt")
    test_features(sess=sess, feature_model=f, samplers=s, f_params=f_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_20.ckpt
# test set error: 0.0019 // time elapsed: 24.0865 s

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=40, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_40")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_40"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_40.ckpt")
    test_features(sess=sess, feature_model=f, samplers=s, f_params=f_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_40.ckpt
# test set error: 0.0021 // time elapsed: 24.2161 s
