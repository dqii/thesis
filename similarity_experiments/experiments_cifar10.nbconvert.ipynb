# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Pair_Hinge_Settings, Pair_Log_Settings, Triplet_Hinge_Settings, Triplet_Log_Settings
from features.models import ConvModelSmall, ConvModelMedium, ConvModelLarge
from features.models import GCNNModelSmall, GCNNModelMedium, GCNNModelLarge
from classes.models import LinearClassifier
from datasets import load_mnist_datasets, load_cifar10
from sklearn.svm import LinearSVC
import time
# Out:
# /home/dqi/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/dqi/.conda/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data, samplers, pair_samplers, triplet_samplers = load_cifar10(augment=True)
# Out:
# CIFAR-10 loaded in 101 seconds

# %%
def test_model(feature_model, settings, data, num_features, num_classes, feature_samplers, classification_samplers,
               f_num_steps, f_lr, f_keep_prob, f_reg, c_num_steps, c_lr, c_reg):
    
    tf.reset_default_graph()
    
    f_train, f_valid, f_test = feature_samplers
    c_train, c_valid, c_test = classification_samplers
    (x_train, y_train), (x_valid, y_valid), (x_test, y_test) = data
    _, H, W, C = x_train.shape
    
    x = tf.placeholder(tf.float32, shape=[None, H, W, C])
    y = tf.placeholder(tf.int64, shape=[None])    
    dropout = tf.placeholder(tf.float32)
    training = tf.placeholder(tf.bool)
    f_model = feature_model(x=x, y=y, settings=settings, num_chan=C, num_features=num_features, 
              lr=f_lr, reg=f_reg, dropout=dropout, training=training)
    
    features = tf.placeholder(tf.float32, shape=[None, num_features])
    c_model = LinearClassifier(x=features, y=y, num_features=num_features, num_classes=num_features, 
                               lr=c_lr, reg=c_reg)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        print("begin training features // num_features: %g, lr: %g, reg: %g, dropout: %g" %(num_features, f_lr, f_reg, f_keep_prob))
        train_time = time.time()
        for step in range(f_num_steps):        
            x_, y_ = f_train.sample(700)
            sess.run(f_model.optimize, feed_dict={x:x_, y:y_, dropout:f_keep_prob, training:True})     
            if step % 1000 == 0:
                train_loss, train_acc = sess.run([f_model.loss, f_model.acc], 
                                                 feed_dict={x:x_, y:y_, dropout:1.0, training:False})
                print("\tstep %d: train loss %g, train error %g"%(step, train_loss, 1 - train_acc))  
        train_time = time.time() - train_time
        print("end training features // time elapsed: %.4f s"%(train_time))
        
        eval_test_time = time.time()
        x_, y_ = f_valid.sample(1000)
        test_error = 1 - sess.run(f_model.acc, feed_dict={x:x_, y:y_, dropout:1.0, training:False})
        eval_test_time = time.time() - eval_test_time
        print("validation set error: %.4f // time elapsed: %.4f s"%(test_error, eval_test_time))
        
        eval_test_time = time.time()
        x_, y_ = f_test.sample(1000)
        test_error = 1 - sess.run(f_model.acc, feed_dict={x:x_, y:y_, dropout:1.0, training:False})
        eval_test_time = time.time() - eval_test_time
        print("test set error: %.4f // time elapsed: %.4f s"%(test_error, eval_test_time))
        
        print("begin training classifier")
        train_time = time.time()
        for step in range(c_num_steps):        
            x_, y_ = c_train.sample(700)
            features_ = sess.run(f_model.features, feed_dict={x:x_, dropout:1.0, training:False})
            sess.run(c_model.optimize, feed_dict={features:features_, y:y_, x:x_, dropout:1.0, training:False})
            if step % 1000 == 0:
                train_loss, train_acc = sess.run([c_model.loss, c_model.acc], feed_dict={features:features_, y:y_})
                print("\tstep %d: train loss %g, train error %g"%(step, train_loss, 1 - train_acc))  
        train_time = time.time() - train_time
        print("end training classifier // time elapsed: %.4f s"%(train_time))
        
        eval_test_time = time.time()
        features_ = sess.run(f_model.features, feed_dict={x:x_valid, dropout:1.0, training:False})
        test_error = 1 - sess.run(c_model.acc, feed_dict={features:features_, y:y_valid})
        eval_test_time = time.time() - eval_test_time
        print("validation set error: %.4f // time elapsed: %.4f s"%(test_error, eval_test_time))
        
        eval_test_time = time.time()
        features_ = sess.run(f_model.features, feed_dict={x:x_test, dropout:1.0, training:False})
        test_error = 1 - sess.run(c_model.acc, feed_dict={features:features_, y:y_test})
        eval_test_time = time.time() - eval_test_time
        print("test set error: %.4f // time elapsed: %.4f s"%(test_error, eval_test_time))

# %%
test_model(feature_model=GCNNModelSmall, settings=Baseline_Settings, num_features=10, num_classes=10,
           data=data, feature_samplers=samplers, classification_samplers=samplers,           
           f_num_steps=70000, f_lr=0.01, f_keep_prob=0.5, f_reg=0.001, 
           c_num_steps=30000, c_lr=0.005, c_reg=0.01)
# Out:
# begin training features // num_features: 10, lr: 0.01, reg: 0.001, dropout: 0.5
# 	step 0: train loss 2.93011, train error 0.9
# 	step 1000: train loss 2.17987, train error 0.617143
# 	step 2000: train loss 1.95676, train error 0.558571
# 	step 3000: train loss 1.88843, train error 0.528571
# 	step 4000: train loss 1.84255, train error 0.535714
# 	step 5000: train loss 1.79822, train error 0.515714
# 	step 6000: train loss 1.6618, train error 0.48
# 	step 7000: train loss 1.71183, train error 0.491429
# 	step 8000: train loss 1.50597, train error 0.448571
# 	step 9000: train loss 1.47371, train error 0.434286
# 	step 10000: train loss 1.51822, train error 0.464286
# 	step 11000: train loss 1.54765, train error 0.458571
# 	step 12000: train loss 1.36541, train error 0.401429
# 	step 13000: train loss 1.32192, train error 0.391429
# 	step 14000: train loss 1.28613, train error 0.377143
# 	step 15000: train loss 1.22978, train error 0.367143
# 	step 16000: train loss 1.25001, train error 0.374286
# 	step 17000: train loss 1.19561, train error 0.357143
# 	step 18000: train loss 1.12773, train error 0.332857
# 	step 19000: train loss 1.0525, train error 0.32
# 	step 20000: train loss 1.08488, train error 0.33
# 	step 21000: train loss 1.06124, train error 0.321429
# 	step 22000: train loss 1.01972, train error 0.305714
# 	step 23000: train loss 0.996976, train error 0.311429
# 	step 24000: train loss 0.928102, train error 0.301429
# 	step 25000: train loss 0.947267, train error 0.298571
# 	step 26000: train loss 0.89694, train error 0.282857
# 	step 27000: train loss 0.911835, train error 0.287143
# 	step 28000: train loss 0.855296, train error 0.254286
# 	step 29000: train loss 0.809444, train error 0.24
# 	step 30000: train loss 0.814032, train error 0.244286
# 	step 31000: train loss 0.838861, train error 0.271429
# 	step 32000: train loss 0.871051, train error 0.284286
# 	step 33000: train loss 0.751236, train error 0.215714
# 	step 34000: train loss 0.781137, train error 0.258571
# 	step 35000: train loss 0.725541, train error 0.227143
# 	step 36000: train loss 0.654667, train error 0.207143
# 	step 37000: train loss 0.715284, train error 0.214286
# 	step 38000: train loss 0.71067, train error 0.227143
# 	step 39000: train loss 0.689014, train error 0.197143
# 	step 40000: train loss 0.700554, train error 0.221429
# 	step 41000: train loss 0.669554, train error 0.205714
# 	step 42000: train loss 0.64631, train error 0.204286
# 	step 43000: train loss 0.683839, train error 0.23
# 	step 44000: train loss 0.574835, train error 0.172857
# 	step 45000: train loss 0.61829, train error 0.191429
# 	step 46000: train loss 0.659693, train error 0.212857
# 	step 47000: train loss 0.594315, train error 0.192857
# 	step 48000: train loss 0.559739, train error 0.174286
# 	step 49000: train loss 0.563966, train error 0.165714
# 	step 50000: train loss 0.554576, train error 0.184286
# 	step 51000: train loss 0.582565, train error 0.18
# 	step 52000: train loss 0.560697, train error 0.162857
# 	step 53000: train loss 0.563256, train error 0.184286
# 	step 54000: train loss 0.51891, train error 0.157143
# 	step 55000: train loss 0.487605, train error 0.141429
# 	step 56000: train loss 0.511418, train error 0.155714
# 	step 57000: train loss 0.488562, train error 0.131429
# 	step 58000: train loss 0.491477, train error 0.134286
# 	step 59000: train loss 0.476239, train error 0.14
# 	step 60000: train loss 0.437995, train error 0.122857
# 	step 61000: train loss 0.445704, train error 0.131429
# 	step 62000: train loss 0.474216, train error 0.13
# 	step 63000: train loss 0.44238, train error 0.121429
# 	step 64000: train loss 0.444383, train error 0.124286
# 	step 65000: train loss 0.449388, train error 0.131429
# 	step 66000: train loss 0.453136, train error 0.125714
# 	step 67000: train loss 0.423383, train error 0.11
# 	step 68000: train loss 0.394549, train error 0.105714
# 	step 69000: train loss 0.409108, train error 0.111429
# end training features // time elapsed: 3733.4845 s
# validation set error: 0.1990 // time elapsed: 0.0804 s
# test set error: 0.1890 // time elapsed: 0.0309 s
# begin training classifier
# 	step 0: train loss 4.63299, train error 0.912857
# 	step 1000: train loss 0.467019, train error 0.132857
# 	step 2000: train loss 0.425706, train error 0.127143
# 	step 3000: train loss 0.396066, train error 0.12
# 	step 4000: train loss 0.328335, train error 0.09
# 	step 5000: train loss 0.392222, train error 0.112857
# 	step 6000: train loss 0.367072, train error 0.108571
# 	step 7000: train loss 0.358445, train error 0.0971429
# 	step 8000: train loss 0.31967, train error 0.107143
# 	step 9000: train loss 0.362452, train error 0.11
# 	step 10000: train loss 0.342225, train error 0.101429
# 	step 11000: train loss 0.363456, train error 0.118571
# 	step 12000: train loss 0.34593, train error 0.115714
# 	step 13000: train loss 0.318616, train error 0.0857143
# 	step 14000: train loss 0.333242, train error 0.11
# 	step 15000: train loss 0.339362, train error 0.104286
# 	step 16000: train loss 0.32126, train error 0.0971429
# 	step 17000: train loss 0.303891, train error 0.0957143
# 	step 18000: train loss 0.325569, train error 0.101429
# 	step 19000: train loss 0.340851, train error 0.0971429
# 	step 20000: train loss 0.325719, train error 0.0957143
# 	step 21000: train loss 0.348289, train error 0.1
# 	step 22000: train loss 0.299984, train error 0.0828571
# 	step 23000: train loss 0.339363, train error 0.114286
# 	step 24000: train loss 0.32053, train error 0.0985714
# 	step 25000: train loss 0.323653, train error 0.09
# 	step 26000: train loss 0.31999, train error 0.0914286
# 	step 27000: train loss 0.314484, train error 0.102857
# 	step 28000: train loss 0.333636, train error 0.112857
# 	step 29000: train loss 0.295455, train error 0.0942857
# end training classifier // time elapsed: 1239.2455 s
# validation set error: 0.1850 // time elapsed: 0.3063 s
# test set error: 0.1924 // time elapsed: 0.4833 s

# %%
test_model(feature_model=GCNNModelSmall, settings=Triplet_Hinge_Settings, num_features=20, num_classes=10,
           data=data, feature_samplers=triplet_samplers, classification_samplers=samplers,           
           f_num_steps=70000, f_lr=0.01, f_keep_prob=0.5, f_reg=0.001, 
           c_num_steps=40000, c_lr=0.01, c_reg=0.1)
# Out:
# begin training features // num_features: 20, lr: 0.01, reg: 0.001, dropout: 0.5
# 	step 0: train loss 1.53422, train error 0.504286
# 	step 1000: train loss 1.30936, train error 0.368571
# 	step 2000: train loss 1.23402, train error 0.344286
# 	step 3000: train loss 1.16887, train error 0.317143
# 	step 4000: train loss 1.17245, train error 0.352857
# 	step 5000: train loss 1.09434, train error 0.317143
# 	step 6000: train loss 1.06942, train error 0.301429
# 	step 7000: train loss 1.04514, train error 0.302857
# 	step 8000: train loss 0.992905, train error 0.288571
# 	step 9000: train loss 0.926068, train error 0.257143
# 	step 10000: train loss 0.933511, train error 0.284286
# 	step 11000: train loss 0.859604, train error 0.272857
# 	step 12000: train loss 0.875563, train error 0.252857
# 	step 13000: train loss 0.867234, train error 0.27
# 	step 14000: train loss 0.865351, train error 0.271429
# 	step 15000: train loss 0.823649, train error 0.264286
# 	step 16000: train loss 0.773278, train error 0.245714
# 	step 17000: train loss 0.77687, train error 0.251429
# 	step 18000: train loss 0.742573, train error 0.255714
# 	step 19000: train loss 0.654115, train error 0.194286
# 	step 20000: train loss 0.718195, train error 0.238571
# 	step 21000: train loss 0.696334, train error 0.234286
# 	step 22000: train loss 0.635596, train error 0.207143
# 	step 23000: train loss 0.602805, train error 0.198571
# 	step 24000: train loss 0.626251, train error 0.21
# 	step 25000: train loss 0.621513, train error 0.202857
# 	step 26000: train loss 0.55734, train error 0.194286
# 	step 27000: train loss 0.61081, train error 0.2
# 	step 28000: train loss 0.51714, train error 0.178571
# 	step 29000: train loss 0.554864, train error 0.192857
# 	step 30000: train loss 0.543319, train error 0.198571
# 	step 31000: train loss 0.549937, train error 0.197143
# 	step 32000: train loss 0.578483, train error 0.218571
# 	step 33000: train loss 0.489495, train error 0.175714
# 	step 34000: train loss 0.431919, train error 0.155714
# 	step 35000: train loss 0.491642, train error 0.182857
# 	step 36000: train loss 0.44294, train error 0.152857
# 	step 37000: train loss 0.465085, train error 0.158571
# 	step 38000: train loss 0.442976, train error 0.168571
# 	step 39000: train loss 0.467489, train error 0.158571
# 	step 40000: train loss 0.445844, train error 0.167143
# 	step 41000: train loss 0.411089, train error 0.15
# 	step 42000: train loss 0.417735, train error 0.157143
# 	step 43000: train loss 0.376072, train error 0.121429
# 	step 44000: train loss 0.407553, train error 0.15
# 	step 45000: train loss 0.443011, train error 0.172857
# 	step 46000: train loss 0.382089, train error 0.134286
# 	step 47000: train loss 0.361558, train error 0.151429
# 	step 48000: train loss 0.39208, train error 0.157143
# 	step 49000: train loss 0.365173, train error 0.12
# 	step 50000: train loss 0.342004, train error 0.127143
# 	step 51000: train loss 0.366898, train error 0.138571
# 	step 52000: train loss 0.40713, train error 0.157143
# 	step 53000: train loss 0.404047, train error 0.142857
# 	step 54000: train loss 0.399282, train error 0.144286
# 	step 55000: train loss 0.322053, train error 0.13
# 	step 56000: train loss 0.360266, train error 0.134286
# 	step 57000: train loss 0.34657, train error 0.124286
# 	step 58000: train loss 0.360684, train error 0.144286
# 	step 59000: train loss 0.343972, train error 0.135714
# 	step 60000: train loss 0.329149, train error 0.127143
# 	step 61000: train loss 0.325579, train error 0.118571
# 	step 62000: train loss 0.315702, train error 0.122857
# 	step 63000: train loss 0.286314, train error 0.101429
# 	step 64000: train loss 0.286739, train error 0.104286
# 	step 65000: train loss 0.316851, train error 0.112857
# 	step 66000: train loss 0.325775, train error 0.118571
# 	step 67000: train loss 0.320874, train error 0.138571
# 	step 68000: train loss 0.331044, train error 0.121429
# 	step 69000: train loss 0.315872, train error 0.117143
# end training features // time elapsed: 11658.0710 s
# validation set error: 0.1270 // time elapsed: 0.2287 s
# test set error: 0.1160 // time elapsed: 0.1626 s
# begin training classifier
# 	step 0: train loss 4.0479, train error 0.855714
# 	step 1000: train loss 1.95134, train error 0.401429
# 	step 2000: train loss 1.68153, train error 0.372857
# 	step 3000: train loss 1.55615, train error 0.36
# 	step 4000: train loss 1.4793, train error 0.342857
# 	step 5000: train loss 1.40909, train error 0.347143
# 	step 6000: train loss 1.39558, train error 0.387143
# 	step 7000: train loss 1.3334, train error 0.351429
# 	step 8000: train loss 1.31155, train error 0.348571
# 	step 9000: train loss 1.26002, train error 0.335714
# 	step 10000: train loss 1.33338, train error 0.392857
# 	step 11000: train loss 1.25377, train error 0.344286
# 	step 12000: train loss 1.23009, train error 0.345714
# 	step 13000: train loss 1.24922, train error 0.335714
# 	step 14000: train loss 1.22826, train error 0.335714
# 	step 15000: train loss 1.20355, train error 0.328571
# 	step 16000: train loss 1.19786, train error 0.338571
# 	step 17000: train loss 1.2322, train error 0.365714
# 	step 18000: train loss 1.20484, train error 0.358571
# 	step 19000: train loss 1.20836, train error 0.371429
# 	step 20000: train loss 1.21701, train error 0.358571
# 	step 21000: train loss 1.20528, train error 0.35
# 	step 22000: train loss 1.11746, train error 0.314286
# 	step 23000: train loss 1.18679, train error 0.367143
# 	step 24000: train loss 1.14727, train error 0.344286
# 	step 25000: train loss 1.19063, train error 0.36
# 	step 26000: train loss 1.15718, train error 0.355714
# 	step 27000: train loss 1.1554, train error 0.347143
# 	step 28000: train loss 1.15839, train error 0.345714
# 	step 29000: train loss 1.15034, train error 0.364286
# 	step 30000: train loss 1.09796, train error 0.324286
# 	step 31000: train loss 1.08634, train error 0.325714
# 	step 32000: train loss 1.08342, train error 0.351429
# 	step 33000: train loss 1.10641, train error 0.312857
# 	step 34000: train loss 1.10644, train error 0.315714
# 	step 35000: train loss 1.10931, train error 0.355714
# 	step 36000: train loss 1.0907, train error 0.322857
# 	step 37000: train loss 1.13132, train error 0.345714
# 	step 38000: train loss 1.07933, train error 0.362857
# 	step 39000: train loss 1.06566, train error 0.352857
# end training classifier // time elapsed: 1656.1524 s
# validation set error: 0.3442 // time elapsed: 0.2172 s
# test set error: 0.3588 // time elapsed: 0.3319 s

# %%
test_model(feature_model=GCNNModelSmall, settings=Triplet_Hinge_Settings, num_features=20, num_classes=10,
           data=data, feature_samplers=triplet_samplers, classification_samplers=samplers,           
           f_num_steps=70000, f_lr=0.01, f_keep_prob=0.6, f_reg=0.001, 
           c_num_steps=40000, c_lr=0.01, c_reg=0.1)
# Out:
# begin training features // num_features: 20, lr: 0.01, reg: 0.001, dropout: 0.6
# 	step 0: train loss 1.52439, train error 0.461429
# 	step 1000: train loss 1.32681, train error 0.381429
# 	step 2000: train loss 1.28268, train error 0.358571
# 	step 3000: train loss 1.13089, train error 0.308571
# 	step 4000: train loss 1.07105, train error 0.275714
# 	step 5000: train loss 0.995504, train error 0.265714
# 	step 6000: train loss 1.00756, train error 0.284286
# 	step 7000: train loss 0.927377, train error 0.257143
# 	step 8000: train loss 0.945428, train error 0.277143
# 	step 9000: train loss 0.924185, train error 0.274286
# 	step 10000: train loss 0.899717, train error 0.281429
# 	step 11000: train loss 0.812311, train error 0.23
# 	step 12000: train loss 0.764345, train error 0.211429
# 	step 13000: train loss 0.759501, train error 0.235714
# 	step 14000: train loss 0.724082, train error 0.202857
# 	step 15000: train loss 0.697143, train error 0.197143
# 	step 16000: train loss 0.659486, train error 0.197143
# 	step 17000: train loss 0.684829, train error 0.205714
# 	step 18000: train loss 0.606532, train error 0.188571
# 	step 19000: train loss 0.603747, train error 0.177143
# 	step 20000: train loss 0.545372, train error 0.162857
# 	step 21000: train loss 0.567939, train error 0.17
# 	step 22000: train loss 0.54813, train error 0.161429
# 	step 23000: train loss 0.547906, train error 0.171429
# 	step 24000: train loss 0.510164, train error 0.155714
# 	step 25000: train loss 0.473173, train error 0.152857
# 	step 26000: train loss 0.462356, train error 0.152857
# 	step 27000: train loss 0.504338, train error 0.15
# 	step 28000: train loss 0.425456, train error 0.118571
# 	step 29000: train loss 0.405045, train error 0.114286
# 	step 30000: train loss 0.417499, train error 0.145714
# 	step 31000: train loss 0.451189, train error 0.145714
# 	step 32000: train loss 0.440919, train error 0.157143
# 	step 33000: train loss 0.395427, train error 0.12
# 	step 34000: train loss 0.360047, train error 0.115714
# 	step 35000: train loss 0.370013, train error 0.117143
# 	step 36000: train loss 0.361302, train error 0.111429
# 	step 37000: train loss 0.351032, train error 0.117143
# 	step 38000: train loss 0.35648, train error 0.128571
# 	step 39000: train loss 0.306955, train error 0.09
# 	step 40000: train loss 0.292479, train error 0.0971429
# 	step 41000: train loss 0.359409, train error 0.124286
# 	step 42000: train loss 0.31021, train error 0.104286
# 	step 43000: train loss 0.302648, train error 0.107143
# 	step 44000: train loss 0.301809, train error 0.0971429
# 	step 45000: train loss 0.315541, train error 0.108571
# 	step 46000: train loss 0.287096, train error 0.0985714
# 	step 47000: train loss 0.262466, train error 0.0828571
# 	step 48000: train loss 0.25331, train error 0.0942857
# 	step 49000: train loss 0.281117, train error 0.1
# 	step 50000: train loss 0.266611, train error 0.0957143
# 	step 51000: train loss 0.270417, train error 0.108571
# 	step 52000: train loss 0.222641, train error 0.0714286
# 	step 53000: train loss 0.258735, train error 0.09
# 	step 54000: train loss 0.196296, train error 0.0614285
# 	step 55000: train loss 0.276259, train error 0.108571
# 	step 56000: train loss 0.225151, train error 0.0828571
# 	step 57000: train loss 0.190895, train error 0.0614285
# 	step 58000: train loss 0.222271, train error 0.0685714
# 	step 59000: train loss 0.245137, train error 0.0757143
# 	step 60000: train loss 0.199112, train error 0.06
# 	step 61000: train loss 0.24849, train error 0.0828571
# 	step 62000: train loss 0.178249, train error 0.0585715
# 	step 63000: train loss 0.209012, train error 0.0642857
# 	step 64000: train loss 0.19724, train error 0.0614285
# 	step 65000: train loss 0.186405, train error 0.0671428
# 	step 66000: train loss 0.209196, train error 0.0642857
# 	step 67000: train loss 0.154661, train error 0.0442857
# 	step 68000: train loss 0.194703, train error 0.0728571
# 	step 69000: train loss 0.184913, train error 0.0614285
# end training features // time elapsed: 11675.8403 s
# validation set error: 0.0870 // time elapsed: 0.2120 s
# test set error: 0.0790 // time elapsed: 0.2102 s
# begin training classifier
# 	step 0: train loss 4.24597, train error 0.99
# 	step 1000: train loss 1.60205, train error 0.19
# 	step 2000: train loss 1.24496, train error 0.171429
# 	step 3000: train loss 1.17941, train error 0.195714
# 	step 4000: train loss 1.05736, train error 0.162857
# 	step 5000: train loss 1.06124, train error 0.208571
# 	step 6000: train loss 1.01139, train error 0.21
# 	step 7000: train loss 0.960859, train error 0.211429
# 	step 8000: train loss 0.923245, train error 0.188571
# 	step 9000: train loss 0.889151, train error 0.182857
# 	step 10000: train loss 0.873131, train error 0.18
# 	step 11000: train loss 0.84723, train error 0.187143
# 	step 12000: train loss 0.864425, train error 0.214286
# 	step 13000: train loss 0.861247, train error 0.204286
# 	step 14000: train loss 0.782418, train error 0.164286
# 	step 15000: train loss 0.854981, train error 0.208571
# 	step 16000: train loss 0.783805, train error 0.184286
# 	step 17000: train loss 0.8374, train error 0.204286
# 	step 18000: train loss 0.775855, train error 0.171429
# 	step 19000: train loss 0.780214, train error 0.185714
# 	step 20000: train loss 0.734419, train error 0.162857
# 	step 21000: train loss 0.707997, train error 0.18
# 	step 22000: train loss 0.774014, train error 0.188571
# 	step 23000: train loss 0.755996, train error 0.188571
# 	step 24000: train loss 0.77049, train error 0.188571
# 	step 25000: train loss 0.757724, train error 0.181429
# 	step 26000: train loss 0.76108, train error 0.218571
# 	step 27000: train loss 0.770505, train error 0.207143
# 	step 28000: train loss 0.697748, train error 0.177143
# 	step 29000: train loss 0.735488, train error 0.202857
# 	step 30000: train loss 0.71144, train error 0.154286
# 	step 31000: train loss 0.714897, train error 0.191429
# 	step 32000: train loss 0.678729, train error 0.174286
# 	step 33000: train loss 0.733204, train error 0.198571
# 	step 34000: train loss 0.711326, train error 0.192857
# 	step 35000: train loss 0.70022, train error 0.174286
# 	step 36000: train loss 0.682461, train error 0.162857
# 	step 37000: train loss 0.722041, train error 0.195714
# 	step 38000: train loss 0.704427, train error 0.187143
# 	step 39000: train loss 0.717403, train error 0.194286
# end training classifier // time elapsed: 1655.2701 s
# validation set error: 0.2390 // time elapsed: 0.2297 s
# test set error: 0.2432 // time elapsed: 0.3627 s
