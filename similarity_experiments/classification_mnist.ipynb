# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Triplet_Hinge_Settings, Triplet_Log_Settings, Pair_Hinge_Settings, Triplet_Distance_Settings
from features.models import CNNSmall0, CNNSmall1, CNNSmall2, CNNMedium0, CNNMedium1
from classes.models import LinearClassifier0, LinearClassifier1, LinearClassifier2, LinearClassifier3, TwoLayerClassifier0
from learn import get_feature_model, get_classifier, train_features, train_classifier, test_model
from datasets import load_mnist
# Out:
# /home/dqi/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/dqi/.conda/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data, samplers, pair_samplers, triplet_samplers = load_mnist(augment=True)
d = data; s=samplers
# Out:
# MNIST loaded in 18 seconds

# %% [markdown]
# # Final Results

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_10")
c, c_params = get_classifier(classifier=TwoLayerClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 3.51295, train error 0.93
# 	step 100: train loss 1.58675, train error 0.521429
# 	step 200: train loss 1.15794, train error 0.258571
# 	step 300: train loss 0.965621, train error 0.155714
# 	step 400: train loss 0.778552, train error 0.0471429
# 	step 500: train loss 0.593309, train error 0.0314286
# 	step 600: train loss 0.502021, train error 0.03
# 	step 700: train loss 0.475019, train error 0.0328571
# 	step 800: train loss 0.421388, train error 0.0271429
# 	step 900: train loss 0.320864, train error 0.0271429
# 	step 1000: train loss 0.309276, train error 0.0371429
# 	step 1100: train loss 0.27738, train error 0.0271429
# 	step 1200: train loss 0.255964, train error 0.0228571
# 	step 1300: train loss 0.230977, train error 0.0271429
# 	step 1400: train loss 0.218307, train error 0.0214286
# 	step 1500: train loss 0.198258, train error 0.0171428
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.40645, train error 0.991429
# 	step 100: train loss 1.66378, train error 0.687143
# 	step 200: train loss 1.20795, train error 0.434286
# 	step 300: train loss 0.929147, train error 0.164286
# 	step 400: train loss 0.792978, train error 0.0471429
# 	step 500: train loss 0.657348, train error 0.0342857
# 	step 600: train loss 0.526685, train error 0.02
# 	step 700: train loss 0.478187, train error 0.0228571
# 	step 800: train loss 0.438603, train error 0.0157143
# 	step 900: train loss 0.377503, train error 0.0257143
# 	step 1000: train loss 0.362531, train error 0.0214286
# 	step 1100: train loss 0.319256, train error 0.0257143
# 	step 1200: train loss 0.282976, train error 0.0157143
# 	step 1300: train loss 0.279702, train error 0.02
# 	step 1400: train loss 0.260376, train error 0.0214286
# 	step 1500: train loss 0.25294, train error 0.0185714
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.389279, train error 0.825714
# 	step 100: train loss 0.350306, train error 0.757143
# 	step 200: train loss 0.319748, train error 0.701429
# 	step 300: train loss 0.307022, train error 0.455714
# 	step 400: train loss 0.289759, train error 0.434286
# 	step 500: train loss 0.271709, train error 0.42
# 	step 600: train loss 0.264534, train error 0.438571
# 	step 700: train loss 0.245212, train error 0.411429
# 	step 800: train loss 0.231519, train error 0.385714
# 	step 900: train loss 0.236295, train error 0.411429
# 	step 1000: train loss 0.228751, train error 0.407143
# 	step 1100: train loss 0.224247, train error 0.407143
# 	step 1200: train loss 0.219705, train error 0.401429
# 	step 1300: train loss 0.213359, train error 0.408571
# 	step 1400: train loss 0.196904, train error 0.361429
# 	step 1500: train loss 0.210127, train error 0.414286
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_20")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=20, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_20"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_20.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_20.ckpt
# begin training classifier
# 	step 0: train loss 3.12925, train error 0.94
# 	step 100: train loss 1.6776, train error 0.61
# 	step 200: train loss 1.18846, train error 0.314286
# 	step 300: train loss 0.93967, train error 0.0771428
# 	step 400: train loss 0.735487, train error 0.0242857
# 	step 500: train loss 0.605321, train error 0.0142857
# 	step 600: train loss 0.552991, train error 0.02
# 	step 700: train loss 0.445089, train error 0.0128571
# 	step 800: train loss 0.42106, train error 0.0214286
# 	step 900: train loss 0.364792, train error 0.0185714
# 	step 1000: train loss 0.346689, train error 0.0257143
# 	step 1100: train loss 0.29672, train error 0.0157143
# 	step 1200: train loss 0.284148, train error 0.0185714
# 	step 1300: train loss 0.268786, train error 0.0114286
# 	step 1400: train loss 0.282846, train error 0.0171428
# 	step 1500: train loss 0.252415, train error 0.0242857
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=20, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_20")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=20, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_20"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_20.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_20.ckpt
# begin training classifier
# 	step 0: train loss 0.385345, train error 0.961429
# 	step 100: train loss 0.345324, train error 0.94
# 	step 200: train loss 0.316724, train error 0.912857
# 	step 300: train loss 0.28611, train error 0.578571
# 	step 400: train loss 0.264668, train error 0.522857
# 	step 500: train loss 0.25356, train error 0.538571
# 	step 600: train loss 0.24441, train error 0.521429
# 	step 700: train loss 0.232937, train error 0.51
# 	step 800: train loss 0.220203, train error 0.49
# 	step 900: train loss 0.2152, train error 0.498571
# 	step 1000: train loss 0.204642, train error 0.452857
# 	step 1100: train loss 0.199422, train error 0.437143
# 	step 1200: train loss 0.197753, train error 0.43
# 	step 1300: train loss 0.190264, train error 0.382857
# 	step 1400: train loss 0.185765, train error 0.304286
# 	step 1500: train loss 0.172155, train error 0.257143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=40, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_40")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=40, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_40"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_40.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_40.ckpt
# begin training classifier
# 	step 0: train loss 2.67281, train error 0.981429
# 	step 100: train loss 1.49969, train error 0.46
# 	step 200: train loss 1.16529, train error 0.268571
# 	step 300: train loss 0.86914, train error 0.0985714
# 	step 400: train loss 0.716858, train error 0.0185714
# 	step 500: train loss 0.643147, train error 0.0228571
# 	step 600: train loss 0.545311, train error 0.0185714
# 	step 700: train loss 0.451939, train error 0.0214286
# 	step 800: train loss 0.431514, train error 0.02
# 	step 900: train loss 0.367285, train error 0.02
# 	step 1000: train loss 0.312156, train error 0.0171428
# 	step 1100: train loss 0.318817, train error 0.00999999
# 	step 1200: train loss 0.298155, train error 0.0157143
# 	step 1300: train loss 0.281369, train error 0.0185714
# 	step 1400: train loss 0.257095, train error 0.0114286
# 	step 1500: train loss 0.238451, train error 0.0171428
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=40, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs1_mnist_40")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=40, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_mnist_40"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/mnist/f_cs1_mnist_40.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/mnist/f_cs1_mnist_40.ckpt
# begin training classifier
# 	step 0: train loss 0.379461, train error 1
# 	step 100: train loss 0.350109, train error 0.998571
# 	step 200: train loss 0.323258, train error 0.955714
# 	step 300: train loss 0.305019, train error 0.688571
# 	step 400: train loss 0.278995, train error 0.67
# 	step 500: train loss 0.271516, train error 0.705714
# 	step 600: train loss 0.263854, train error 0.685714
# 	step 700: train loss 0.244875, train error 0.627143
# 	step 800: train loss 0.242301, train error 0.56
# 	step 900: train loss 0.22416, train error 0.468571
# 	step 1000: train loss 0.220312, train error 0.472857
# 	step 1100: train loss 0.214092, train error 0.44
# 	step 1200: train loss 0.206123, train error 0.405714
# 	step 1300: train loss 0.198129, train error 0.385714
# 	step 1400: train loss 0.193581, train error 0.372857
# 	step 1500: train loss 0.199375, train error 0.387143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Distance_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/d_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/d_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.71288, train error 0.991429
# 	step 100: train loss 1.95465, train error 0.648571
# 	step 200: train loss 1.60851, train error 0.595714
# 	step 300: train loss 1.44998, train error 0.507143
# 	step 400: train loss 1.30144, train error 0.427143
# 	step 500: train loss 1.25614, train error 0.387143
# 	step 600: train loss 1.17188, train error 0.304286
# 	step 700: train loss 1.10261, train error 0.242857
# 	step 800: train loss 1.04175, train error 0.22
# 	step 900: train loss 0.949085, train error 0.182857
# 	step 1000: train loss 0.916369, train error 0.172857
# 	step 1100: train loss 0.877649, train error 0.151429
# 	step 1200: train loss 0.823042, train error 0.105714
# 	step 1300: train loss 0.764485, train error 0.0857143
# 	step 1400: train loss 0.728307, train error 0.0628572
# 	step 1500: train loss 0.708226, train error 0.06
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Distance_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/d_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/d_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.33943, train error 0.945714
# 	step 100: train loss 0.328743, train error 0.947143
# 	step 200: train loss 0.312762, train error 0.92
# 	step 300: train loss 0.304107, train error 0.611429
# 	step 400: train loss 0.294339, train error 0.605714
# 	step 500: train loss 0.293499, train error 0.64
# 	step 600: train loss 0.281704, train error 0.62
# 	step 700: train loss 0.267309, train error 0.578571
# 	step 800: train loss 0.269789, train error 0.607143
# 	step 900: train loss 0.266473, train error 0.61
# 	step 1000: train loss 0.264294, train error 0.612857
# 	step 1100: train loss 0.260909, train error 0.614286
# 	step 1200: train loss 0.25323, train error 0.605714
# 	step 1300: train loss 0.250342, train error 0.594286
# 	step 1400: train loss 0.240849, train error 0.547143
# 	step 1500: train loss 0.244673, train error 0.567143
# ...

# %% [markdown]
# # Two Layer Classifier 0

# %%
# 0.0150
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=TwoLayerClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.57778, train error 0.917143
# 	step 100: train loss 1.58695, train error 0.577143
# 	step 200: train loss 1.30028, train error 0.485714
# 	step 300: train loss 1.09977, train error 0.298571
# 	step 400: train loss 0.852323, train error 0.132857
# 	step 500: train loss 0.755273, train error 0.127143
# 	step 600: train loss 0.710443, train error 0.124286
# 	step 700: train loss 0.606341, train error 0.107143
# 	step 800: train loss 0.538499, train error 0.108571
# 	step 900: train loss 0.459742, train error 0.0785714
# 	step 1000: train loss 0.399542, train error 0.0242857
# 	step 1100: train loss 0.347943, train error 0.0314286
# 	step 1200: train loss 0.337235, train error 0.0271429
# 	step 1300: train loss 0.28394, train error 0.0271429
# 	step 1400: train loss 0.289681, train error 0.0357143
# 	step 1500: train loss 0.242805, train error 0.0228571
# ...

# %%
# test different regularization rate: 0.0001; 
# 0.0148
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=TwoLayerClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.42734, train error 0.962857
# 	step 100: train loss 1.29672, train error 0.475714
# 	step 200: train loss 1.02811, train error 0.277143
# 	step 300: train loss 0.776961, train error 0.122857
# 	step 400: train loss 0.634089, train error 0.0771428
# 	step 500: train loss 0.585462, train error 0.0685714
# 	step 600: train loss 0.473444, train error 0.0471429
# 	step 700: train loss 0.399878, train error 0.0342857
# 	step 800: train loss 0.346192, train error 0.03
# 	step 900: train loss 0.30427, train error 0.0314286
# 	step 1000: train loss 0.249194, train error 0.0228571
# 	step 1100: train loss 0.254049, train error 0.0328571
# 	step 1200: train loss 0.212135, train error 0.0242857
# 	step 1300: train loss 0.208315, train error 0.0271429
# 	step 1400: train loss 0.183255, train error 0.0257143
# 	step 1500: train loss 0.181716, train error 0.0228571
# ...

# %% [markdown]
# # Two Layer Classifier 1

# %%
# 0.0162
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=TwoLayerClassifier1, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.83035, train error 0.93
# 	step 100: train loss 1.60415, train error 0.607143
# 	step 200: train loss 1.23737, train error 0.331429
# 	step 300: train loss 0.939377, train error 0.147143
# 	step 400: train loss 0.734979, train error 0.0642857
# 	step 500: train loss 0.626024, train error 0.0371429
# 	step 600: train loss 0.517678, train error 0.0285714
# 	step 700: train loss 0.462538, train error 0.0314286
# 	step 800: train loss 0.37657, train error 0.0271429
# 	step 900: train loss 0.343893, train error 0.0314286
# 	step 1000: train loss 0.290703, train error 0.0242857
# 	step 1100: train loss 0.26223, train error 0.0228571
# 	step 1200: train loss 0.24079, train error 0.02
# 	step 1300: train loss 0.23338, train error 0.0271429
# 	step 1400: train loss 0.201678, train error 0.0157143
# 	step 1500: train loss 0.214269, train error 0.0242857
# ...

# %%
# 0.0160
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=TwoLayerClassifier1, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.09181, train error 0.684286
# 	step 100: train loss 1.65468, train error 0.565714
# 	step 200: train loss 1.51433, train error 0.537143
# 	step 300: train loss 1.40346, train error 0.498571
# 	step 400: train loss 1.33496, train error 0.485714
# 	step 500: train loss 1.28506, train error 0.475714
# 	step 600: train loss 1.21046, train error 0.415714
# 	step 700: train loss 1.17546, train error 0.41
# 	step 800: train loss 1.15529, train error 0.441429
# 	step 900: train loss 1.13005, train error 0.437143
# 	step 1000: train loss 0.990269, train error 0.331429
# 	step 1100: train loss 0.901294, train error 0.272857
# 	step 1200: train loss 0.876072, train error 0.28
# 	step 1300: train loss 0.804973, train error 0.212857
# 	step 1400: train loss 0.734102, train error 0.19
# 	step 1500: train loss 0.607413, train error 0.12
# ...

# %% [markdown]
# # Linear Classifier 0

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 3.11482, train error 0.997143
# 	step 100: train loss 1.50007, train error 0.568571
# 	step 200: train loss 1.04587, train error 0.148571
# 	step 300: train loss 0.767721, train error 0.108571
# 	step 400: train loss 0.593321, train error 0.0242857
# 	step 500: train loss 0.474613, train error 0.0342857
# 	step 600: train loss 0.388356, train error 0.02
# 	step 700: train loss 0.343211, train error 0.0285714
# 	step 800: train loss 0.332281, train error 0.0271429
# 	step 900: train loss 0.294539, train error 0.0257143
# 	step 1000: train loss 0.255923, train error 0.0214286
# 	step 1100: train loss 0.258142, train error 0.0242857
# 	step 1200: train loss 0.25816, train error 0.0328571
# 	step 1300: train loss 0.234361, train error 0.0271429
# 	step 1400: train loss 0.192467, train error 0.0257143
# 	step 1500: train loss 0.221641, train error 0.0328571
# ...

# %%
# 0.0148
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.8494, train error 0.87
# 	step 100: train loss 1.19303, train error 0.21
# 	step 200: train loss 0.802285, train error 0.0928571
# 	step 300: train loss 0.59697, train error 0.04
# 	step 400: train loss 0.4909, train error 0.03
# 	step 500: train loss 0.40824, train error 0.0371429
# 	step 600: train loss 0.348051, train error 0.03
# 	step 700: train loss 0.310136, train error 0.0157143
# 	step 800: train loss 0.255833, train error 0.0171428
# 	step 900: train loss 0.242086, train error 0.0257143
# 	step 1000: train loss 0.23153, train error 0.0185714
# 	step 1100: train loss 0.215414, train error 0.0271429
# 	step 1200: train loss 0.208075, train error 0.0214286
# 	step 1300: train loss 0.221042, train error 0.0271429
# 	step 1400: train loss 0.203362, train error 0.0314286
# 	step 1500: train loss 0.189972, train error 0.0257143
# ...

# %% [markdown]
# # Linear Classifier 1

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier1, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.76947, train error 0.994286
# 	step 100: train loss 1.37987, train error 0.522857
# 	step 200: train loss 0.876508, train error 0.332857
# 	step 300: train loss 0.740048, train error 0.238571
# 	step 400: train loss 0.541472, train error 0.127143
# 	step 500: train loss 0.469546, train error 0.114286
# 	step 600: train loss 0.356182, train error 0.0728571
# 	step 700: train loss 0.401648, train error 0.0971429
# 	step 800: train loss 0.310336, train error 0.0585715
# 	step 900: train loss 0.30298, train error 0.0685714
# 	step 1000: train loss 0.304312, train error 0.07
# 	step 1100: train loss 0.275853, train error 0.06
# 	step 1200: train loss 0.258386, train error 0.0628572
# 	step 1300: train loss 0.283551, train error 0.0685714
# 	step 1400: train loss 0.260824, train error 0.0585715
# 	step 1500: train loss 0.262681, train error 0.0671428
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier1, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.78304, train error 0.922857
# 	step 100: train loss 1.46788, train error 0.455714
# 	step 200: train loss 0.917118, train error 0.157143
# 	step 300: train loss 0.639199, train error 0.131429
# 	step 400: train loss 0.468291, train error 0.0685714
# 	step 500: train loss 0.407523, train error 0.0571429
# 	step 600: train loss 0.332825, train error 0.0428572
# 	step 700: train loss 0.2604, train error 0.04
# 	step 800: train loss 0.274263, train error 0.0471429
# 	step 900: train loss 0.21663, train error 0.0314286
# 	step 1000: train loss 0.241184, train error 0.0414286
# 	step 1100: train loss 0.211535, train error 0.0385714
# 	step 1200: train loss 0.21078, train error 0.0314286
# 	step 1300: train loss 0.172068, train error 0.0328571
# 	step 1400: train loss 0.162121, train error 0.0242857
# 	step 1500: train loss 0.183062, train error 0.0328571
# ...

# %% [markdown]
# # Linear Classifier 2

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.434722, train error 0.988571
# 	step 100: train loss 0.400313, train error 0.974286
# 	step 200: train loss 0.385641, train error 0.941429
# 	step 300: train loss 0.364507, train error 0.905714
# 	step 400: train loss 0.343366, train error 0.635714
# 	step 500: train loss 0.331023, train error 0.631429
# 	step 600: train loss 0.316227, train error 0.614286
# 	step 700: train loss 0.310865, train error 0.638571
# 	step 800: train loss 0.295303, train error 0.62
# 	step 900: train loss 0.281488, train error 0.617143
# 	step 1000: train loss 0.279458, train error 0.627143
# 	step 1100: train loss 0.270968, train error 0.615714
# 	step 1200: train loss 0.262613, train error 0.624286
# 	step 1300: train loss 0.263652, train error 0.627143
# 	step 1400: train loss 0.248602, train error 0.597143
# 	step 1500: train loss 0.244714, train error 0.601429
# ...

# %%
# 0.0166
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.339181, train error 0.905714
# 	step 100: train loss 0.31553, train error 0.847143
# 	step 200: train loss 0.296662, train error 0.62
# 	step 300: train loss 0.286821, train error 0.607143
# 	step 400: train loss 0.264322, train error 0.55
# 	step 500: train loss 0.264757, train error 0.602857
# 	step 600: train loss 0.247306, train error 0.577143
# 	step 700: train loss 0.235019, train error 0.562857
# 	step 800: train loss 0.229771, train error 0.548571
# 	step 900: train loss 0.222764, train error 0.554286
# 	step 1000: train loss 0.218686, train error 0.538571
# 	step 1100: train loss 0.211374, train error 0.528571
# 	step 1200: train loss 0.198986, train error 0.485714
# 	step 1300: train loss 0.203776, train error 0.508571
# 	step 1400: train loss 0.193809, train error 0.474286
# 	step 1500: train loss 0.201055, train error 0.482857
# ...

# %% [markdown]
# # Linear Classifier 3

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier3, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.395137, train error 0.928571
# 	step 100: train loss 0.345249, train error 0.905714
# 	step 200: train loss 0.317451, train error 0.942857
# 	step 300: train loss 0.278424, train error 0.582857
# 	step 400: train loss 0.257745, train error 0.544286
# 	step 500: train loss 0.220493, train error 0.435714
# 	step 600: train loss 0.213508, train error 0.447143
# 	step 700: train loss 0.191711, train error 0.387143
# 	step 800: train loss 0.193736, train error 0.388571
# 	step 900: train loss 0.172236, train error 0.341429
# 	step 1000: train loss 0.169572, train error 0.338571
# 	step 1100: train loss 0.159725, train error 0.318571
# 	step 1200: train loss 0.157579, train error 0.322857
# 	step 1300: train loss 0.153963, train error 0.315714
# 	step 1400: train loss 0.140232, train error 0.288571
# 	step 1500: train loss 0.136857, train error 0.282857
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier3, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.0001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.344749, train error 0.947143
# 	step 100: train loss 0.309393, train error 0.657143
# 	step 200: train loss 0.279295, train error 0.644286
# 	step 300: train loss 0.259352, train error 0.644286
# 	step 400: train loss 0.236458, train error 0.597143
# 	step 500: train loss 0.218876, train error 0.554286
# 	step 600: train loss 0.214229, train error 0.564286
# 	step 700: train loss 0.204474, train error 0.531429
# 	step 800: train loss 0.18787, train error 0.48
# 	step 900: train loss 0.184682, train error 0.471429
# 	step 1000: train loss 0.170674, train error 0.435714
# 	step 1100: train loss 0.166025, train error 0.412857
# 	step 1200: train loss 0.154861, train error 0.377143
# 	step 1300: train loss 0.1479, train error 0.341429
# 	step 1400: train loss 0.140966, train error 0.287143
# 	step 1500: train loss 0.138211, train error 0.285714
# ...

# %% [markdown]
# # Only part of data available for training classifier

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 2.48274, train error 0.765714, valid loss 2.15569, valid error 0.644286
# 	step 100: train loss 0.986696, train error 0.154286, valid loss 1.20007, valid error 0.217143
# 	step 200: train loss 0.716543, train error 0.0542857, valid loss 0.806338, valid error 0.04
# 	step 300: train loss 0.502007, train error 0.0257143, valid loss 0.559267, valid error 0.02
# 	step 400: train loss 0.400408, train error 0.0185714, valid loss 0.420273, valid error 0.0314286
# 	step 500: train loss 0.360918, train error 0.0242857, valid loss 0.368571, valid error 0.0114286
# 	step 600: train loss 0.305802, train error 0.0257143, valid loss 0.311643, valid error 0.0228571
# 	step 700: train loss 0.290498, train error 0.0171428, valid loss 0.277953, valid error 0.00999999
# 	step 800: train loss 0.27777, train error 0.0271429, valid loss 0.277336, valid error 0.0314286
# ...

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="f_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/f_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 0.344129, train error 0.86, valid loss 0.338055, valid error 0.78
# 	step 100: train loss 0.31961, train error 0.862857, valid loss 0.327422, valid error 0.802857
# 	step 200: train loss 0.293473, train error 0.617143, valid loss 0.321386, valid error 0.807143
# 	step 300: train loss 0.264674, train error 0.525714, valid loss 0.29643, valid error 0.67
# 	step 400: train loss 0.248534, train error 0.514286, valid loss 0.298353, valid error 0.697143
# 	step 500: train loss 0.223105, train error 0.474286, valid loss 0.286162, valid error 0.71
# 	step 600: train loss 0.224585, train error 0.515714, valid loss 0.281813, valid error 0.671429
# 	step 700: train loss 0.203999, train error 0.4375, valid loss 0.271271, valid error 0.628571
# 	step 800: train loss 0.22063, train error 0.475714, valid loss 0.266559, valid error 0.577143
# ...

# %% [markdown]
# # Evaluate Baseline

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="b_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/b_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/b_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 7.5177, train error 0.69, valid loss 9.53895, valid error 0.892857
# 	step 100: train loss 0.129611, train error 0.0328571, valid loss 0.0989612, valid error 0.0228571
# 	step 200: train loss 0.0635504, train error 0.0128571, valid loss 0.0721801, valid error 0.0185714
# 	step 300: train loss 0.0922491, train error 0.0314286, valid loss 0.0763516, valid error 0.0228571
# 	step 400: train loss 0.0567444, train error 0.0142857, valid loss 0.0529713, valid error 0.0128571
# 	step 500: train loss 0.0841068, train error 0.0228571, valid loss 0.051503, valid error 0.0114286
# 	step 600: train loss 0.0676696, train error 0.0157143, valid loss 0.0605101, valid error 0.0157143
# 	step 700: train loss 0.0648722, train error 0.0171428, valid loss 0.023951, valid error 0
# 	step 800: train loss 0.0552548, train error 0.0171428, valid loss 0.0523057, valid error 0.0157143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="b_cs0_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs0_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/b_cs0_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/b_cs0_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 1.38514, train error 0.92, valid loss 1.24031, valid error 0.922857
# 	step 100: train loss 0.674953, train error 0.882857, valid loss 0.771782, valid error 0.847143
# 	step 200: train loss 0.36823, train error 0.498571, valid loss 0.517059, valid error 0.722857
# 	step 300: train loss 0.271109, train error 0.415714, valid loss 0.323718, valid error 0.55
# 	step 400: train loss 0.186276, train error 0.351429, valid loss 0.23143, valid error 0.424286
# 	step 500: train loss 0.135383, train error 0.275714, valid loss 0.150454, valid error 0.298571
# 	step 600: train loss 0.0786961, train error 0.145714, valid loss 0.102032, valid error 0.184286
# 	step 700: train loss 0.0618311, train error 0.117143, valid loss 0.0705259, valid error 0.102857
# 	step 800: train loss 0.0475627, train error 0.0757143, valid loss 0.0513009, valid error 0.0685714
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="b_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/b_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/b_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 1.26214, train error 0.818571, valid loss 1.09271, valid error 0.788571
# 	step 100: train loss 0.427346, train error 0.448571, valid loss 0.55765, valid error 0.572857
# 	step 200: train loss 0.271528, train error 0.327143, valid loss 0.379186, valid error 0.431429
# 	step 300: train loss 0.173591, train error 0.284286, valid loss 0.202851, valid error 0.348571
# 	step 400: train loss 0.097793, train error 0.212857, valid loss 0.124613, valid error 0.272857
# 	step 500: train loss 0.0542744, train error 0.0842857, valid loss 0.0607798, valid error 0.0785714
# 	step 600: train loss 0.0381618, train error 0.0557143, valid loss 0.0457375, valid error 0.0628572
# 	step 700: train loss 0.0361191, train error 0.0485714, valid loss 0.0414172, valid error 0.06
# 	step 800: train loss 0.0375619, train error 0.0542857, valid loss 0.0342127, valid error 0.05
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="b_cs1_mnist_10")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs1_mnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/b_cs1_mnist_10.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/b_cs1_mnist_10.ckpt
# begin training classifier
# 	step 0: train loss 1.49508, train error 0.955714, valid loss 1.26505, valid error 0.935714
# 	step 100: train loss 0.890555, train error 0.877143, valid loss 0.769733, valid error 0.831429
# 	step 200: train loss 0.283737, train error 0.522857, valid loss 0.341762, valid error 0.635714
# 	step 300: train loss 0.139086, train error 0.244286, valid loss 0.156214, valid error 0.28
# 	step 400: train loss 0.07003, train error 0.121429, valid loss 0.088018, valid error 0.141429
# 	step 500: train loss 0.0517071, train error 0.0857143, valid loss 0.0564002, valid error 0.0857143
# 	step 600: train loss 0.0407934, train error 0.06, valid loss 0.0410613, valid error 0.0585715
# 	step 700: train loss 0.0342549, train error 0.0457143, valid loss 0.0321467, valid error 0.0442857
# 	step 800: train loss 0.0340865, train error 0.0414286, valid loss 0.0299685, valid error 0.0314286
# ...

# %% [markdown]
# # Evaluate Small Baseline

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="sb_cs0_mnist_10_")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.02, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/sb_cs0_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/sb_cs0_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 3.81428, train error 0.594286, valid loss 5.26621, valid error 0.77
# 	step 100: train loss 0.136704, train error 0.0457143, valid loss 0.132884, valid error 0.0357143
# 	step 200: train loss 0.0834426, train error 0.0271429, valid loss 0.0969409, valid error 0.03
# 	step 300: train loss 0.0802266, train error 0.0228571, valid loss 0.0911731, valid error 0.03
# 	step 400: train loss 0.075613, train error 0.0171428, valid loss 0.0653123, valid error 0.0185714
# 	step 500: train loss 0.0825489, train error 0.0228571, valid loss 0.0736465, valid error 0.0214286
# 	step 600: train loss 0.0801771, train error 0.0242857, valid loss 0.0513731, valid error 0.0114286
# 	step 700: train loss 0.0655544, train error 0.0157143, valid loss 0.0511441, valid error 0.00999999
# 	step 800: train loss 0.091476, train error 0.0342857, valid loss 0.0475521, valid error 0.0114286
# ...

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="sb_cs0_mnist_10_")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/sb_cs0_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/sb_cs0_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 0.80423, train error 0.597143, valid loss 1.10101, valid error 0.807143
# 	step 100: train loss 0.543231, train error 0.531429, valid loss 0.759599, valid error 0.73
# 	step 200: train loss 0.404229, train error 0.448571, valid loss 0.581518, valid error 0.62
# 	step 300: train loss 0.314549, train error 0.408571, valid loss 0.423498, valid error 0.58
# 	step 400: train loss 0.224132, train error 0.334286, valid loss 0.280026, valid error 0.438571
# 	step 500: train loss 0.151401, train error 0.247143, valid loss 0.200741, valid error 0.337143
# 	step 600: train loss 0.107934, train error 0.158571, valid loss 0.111601, valid error 0.181429
# 	step 700: train loss 0.0598196, train error 0.08, valid loss 0.0673881, valid error 0.1
# 	step 800: train loss 0.049692, train error 0.0685714, valid loss 0.0516394, valid error 0.0657143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="sb_cs1_mnist_10_")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.015, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs1_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/sb_cs1_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/sb_cs1_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 7.54342, train error 0.92, valid loss 10.6686, valid error 0.921429
# 	step 100: train loss 0.1647, train error 0.0442857, valid loss 0.0595055, valid error 0
# 	step 200: train loss 0.124332, train error 0.03, valid loss 0.0955935, valid error 0.03
# 	step 300: train loss 0.108288, train error 0.0314286, valid loss 0.0857982, valid error 0.0142857
# 	step 400: train loss 0.0844834, train error 0.0242857, valid loss 0.0482683, valid error 0.00999999
# 	step 500: train loss 0.0611656, train error 0.0142857, valid loss 0.0644864, valid error 0.0185714
# 	step 600: train loss 0.0612708, train error 0.0128571, valid loss 0.0931778, valid error 0.0242857
# 	step 700: train loss 0.075984, train error 0.0242857, valid loss 0.0723807, valid error 0.0228571
# 	step 800: train loss 0.0730527, train error 0.0242857, valid loss 0.057013, valid error 0.0157143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="sb_cs1_mnist_10_")
c, c_params = get_classifier(classifier=LinearClassifier2, num_features=10, num_classes=10, 
                             c_lr=0.015, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs1_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/sb_cs1_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/sb_cs1_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 1.00198, train error 0.938571, valid loss 1.19159, valid error 0.908571
# 	step 100: train loss 0.429999, train error 0.474286, valid loss 0.581903, valid error 0.607143
# 	step 200: train loss 0.232376, train error 0.327143, valid loss 0.32567, valid error 0.444286
# 	step 300: train loss 0.163034, train error 0.271429, valid loss 0.202506, valid error 0.324286
# 	step 400: train loss 0.086668, train error 0.178571, valid loss 0.113731, valid error 0.24
# 	step 500: train loss 0.0566378, train error 0.0857143, valid loss 0.0572266, valid error 0.1
# 	step 600: train loss 0.048232, train error 0.0828571, valid loss 0.0448721, valid error 0.0628572
# 	step 700: train loss 0.0329762, train error 0.0385714, valid loss 0.0334971, valid error 0.0414286
# 	step 800: train loss 0.0366088, train error 0.0442857, valid loss 0.0343702, valid error 0.0471429
# ...

# %% [markdown]
# # Distance

# %%
# 0.0144
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs0_mnist_10_")
c, c_params = get_classifier(classifier=LinearClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.015, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/d_cs0_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
    test_model(sess=sess, feature_model=f, classifier=c, samplers=s, data=d, f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/d_cs0_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 2.49257, train error 0.955714
# 	step 100: train loss 1.83387, train error 0.668571
# 	step 200: train loss 1.61829, train error 0.654286
# 	step 300: train loss 1.48322, train error 0.547143
# 	step 400: train loss 1.309, train error 0.39
# 	step 500: train loss 1.22032, train error 0.264286
# 	step 600: train loss 1.03614, train error 0.154286
# 	step 700: train loss 1.00962, train error 0.148571
# 	step 800: train loss 0.925979, train error 0.135714
# 	step 900: train loss 0.828496, train error 0.108571
# 	step 1000: train loss 0.773797, train error 0.0757143
# 	step 1100: train loss 0.721531, train error 0.0485714
# 	step 1200: train loss 0.692752, train error 0.0528572
# 	step 1300: train loss 0.678245, train error 0.0614285
# 	step 1400: train loss 0.61864, train error 0.0514286
# 	step 1500: train loss 0.602638, train error 0.0428572
# ...

# %%
# 0.0150
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.07, f_reg=0.001, f_scope="d_cs0_mnist_10_")
c, c_params = get_classifier(classifier=TwoLayerClassifier0, num_features=10, num_classes=10, 
                             c_lr=0.01, c_reg=0.001, c_scope="meh", f_params=f_params)
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "d_cs0_mnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/d_cs0_mnist_10_.ckpt")
    train_classifier(sess=sess, feature_model=f, classifier=c, data=d, samplers=s, num_steps=10000, 
                     f_params=f_params, c_params=c_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/d_cs0_mnist_10_.ckpt
# begin training classifier
# 	step 0: train loss 2.17746, train error 0.66
# 	step 100: train loss 1.60182, train error 0.56
# 	step 200: train loss 1.44748, train error 0.452857
# 	step 300: train loss 1.31252, train error 0.367143
# 	step 400: train loss 1.15792, train error 0.31
# 	step 500: train loss 1.02392, train error 0.268571
# 	step 600: train loss 0.930585, train error 0.204286
# 	step 700: train loss 0.850403, train error 0.151429
# 	step 800: train loss 0.77993, train error 0.101429
# 	step 900: train loss 0.687782, train error 0.0685714
# 	step 1000: train loss 0.661836, train error 0.0557143
# 	step 1100: train loss 0.571138, train error 0.0328571
# 	step 1200: train loss 0.560244, train error 0.04
# 	step 1300: train loss 0.482347, train error 0.0457143
# 	step 1400: train loss 0.485916, train error 0.0485714
# 	step 1500: train loss 0.442969, train error 0.0457143
# ...
