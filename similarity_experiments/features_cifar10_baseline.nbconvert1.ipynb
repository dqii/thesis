# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Triplet_Hinge_Settings, Triplet_Log_Settings, Pair_Hinge_Settings
from features.models import GCNNSmall0, GCNNMedium0, GCNNMedium1, GCNNLarge0
from learn import get_feature_model, train_features, test_features
from datasets import load_cifar10
from classes.models import LinearClassifier0, LinearClassifier1, LinearClassifier2, LinearClassifier3, TwoLayerClassifier0, TwoLayerClassifier1
from learn import get_feature_model, get_classifier, train_features, train_classifier, test_model
# Out:
# /home/dqi/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/dqi/.conda/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data, samplers, pair_samplers, triplet_samplers = load_cifar10(augment=True)
# Out:
# CIFAR-10 loaded in 101 seconds

# %%
d=data; s=samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNMedium1, settings=Baseline_Settings,
                                num_features=10, data_format=[32, 32, 3],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gm1_cifar10_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gm1_cifar10_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.7, f_params=f_params)
    fs.save(sess, "./models/cifar10/b_gm1_cifar10_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.82547, train error 0.885
# 	step 200: train loss 2.78678, train error 0.775
# 	step 400: train loss 1.94219, train error 0.585
# 	step 600: train loss 1.83676, train error 0.54
# 	step 800: train loss 1.53603, train error 0.4425
# 	step 1000: train loss 1.65001, train error 0.4925
# 	step 1200: train loss 1.3463, train error 0.365
# 	step 1400: train loss 2.12751, train error 0.6125
# 	step 1600: train loss 1.22557, train error 0.345
# 	step 1800: train loss 1.23366, train error 0.355
# 	step 2000: train loss 1.10868, train error 0.2975
# 	step 2200: train loss 1.19522, train error 0.3725
# 	step 2400: train loss 1.00606, train error 0.2575
# 	step 2600: train loss 1.00354, train error 0.2775
# 	step 2800: train loss 1.23903, train error 0.36
# 	step 3000: train loss 0.941907, train error 0.28
# 	step 3200: train loss 0.954094, train error 0.2575
# 	step 3400: train loss 0.828775, train error 0.24
# 	step 3600: train loss 0.7778, train error 0.22
# 	step 3800: train loss 0.81189, train error 0.22
# 	step 4000: train loss 0.916745, train error 0.2775
# 	step 4200: train loss 0.815491, train error 0.2275
# 	step 4400: train loss 0.739566, train error 0.215
# 	step 4600: train loss 0.834922, train error 0.245
# 	step 4800: train loss 0.693334, train error 0.2075
# 	step 5000: train loss 0.641993, train error 0.175
# 	step 5200: train loss 0.655682, train error 0.1925
# 	step 5400: train loss 0.673258, train error 0.1775
# 	step 5600: train loss 0.545089, train error 0.155
# 	step 5800: train loss 0.649301, train error 0.195
# 	step 6000: train loss 0.660247, train error 0.205
# 	step 6200: train loss 0.603765, train error 0.1575
# 	step 6400: train loss 0.573208, train error 0.1525
# 	step 6600: train loss 0.61537, train error 0.2
# 	step 6800: train loss 0.785102, train error 0.25
# 	step 7000: train loss 0.48633, train error 0.1175
# 	step 7200: train loss 0.499899, train error 0.14
# 	step 7400: train loss 0.506868, train error 0.1325
# 	step 7600: train loss 0.480785, train error 0.1425
# 	step 7800: train loss 0.448649, train error 0.1225
# 	step 8000: train loss 0.422032, train error 0.11
# 	step 8200: train loss 0.424953, train error 0.1125
# 	step 8400: train loss 0.432429, train error 0.1025
# 	step 8600: train loss 0.376254, train error 0.0925
# 	step 8800: train loss 0.343968, train error 0.0625
# 	step 9000: train loss 0.434543, train error 0.115
# 	step 9200: train loss 0.390644, train error 0.09
# 	step 9400: train loss 0.424626, train error 0.115
# 	step 9600: train loss 0.402983, train error 0.1175
# 	step 9800: train loss 0.485909, train error 0.15
# 	step 10000: train loss 0.434841, train error 0.1375
# 	step 10200: train loss 0.394135, train error 0.1
# 	step 10400: train loss 0.465972, train error 0.145
# 	step 10600: train loss 0.329398, train error 0.0825
# 	step 10800: train loss 0.301817, train error 0.0775
# 	step 11000: train loss 0.302477, train error 0.0625
# 	step 11200: train loss 0.260966, train error 0.0625
# 	step 11400: train loss 0.672319, train error 0.22
# 	step 11600: train loss 0.320563, train error 0.08
# 	step 11800: train loss 0.307241, train error 0.0775
# 	step 12000: train loss 0.323467, train error 0.0775
# 	step 12200: train loss 0.300046, train error 0.0575
# 	step 12400: train loss 0.253744, train error 0.05
# 	step 12600: train loss 0.268435, train error 0.05
# 	step 12800: train loss 0.283449, train error 0.065
# 	step 13000: train loss 0.328188, train error 0.0775
# 	step 13200: train loss 0.303267, train error 0.0725
# 	step 13400: train loss 0.243436, train error 0.0375
# 	step 13600: train loss 0.309392, train error 0.0725
# 	step 13800: train loss 0.231723, train error 0.0375
# 	step 14000: train loss 0.238267, train error 0.0475
# 	step 14200: train loss 0.226795, train error 0.035
# 	step 14400: train loss 0.254783, train error 0.0425
# 	step 14600: train loss 0.27939, train error 0.06
# 	step 14800: train loss 0.211773, train error 0.035
# 	step 15000: train loss 0.280287, train error 0.05
# 	step 15200: train loss 0.290907, train error 0.0725
# 	step 15400: train loss 0.251722, train error 0.0425
# 	step 15600: train loss 0.240263, train error 0.0475
# 	step 15800: train loss 0.222616, train error 0.0325
# 	step 16000: train loss 0.202972, train error 0.0275
# 	step 16200: train loss 0.209794, train error 0.0275
# 	step 16400: train loss 0.227652, train error 0.04
# 	step 16600: train loss 0.252657, train error 0.04
# 	step 16800: train loss 0.22609, train error 0.0375
# 	step 17000: train loss 0.387517, train error 0.085
# 	step 17200: train loss 0.232092, train error 0.0425
# 	step 17400: train loss 0.189524, train error 0.0175
# 	step 17600: train loss 0.184457, train error 0.02
# 	step 17800: train loss 0.195226, train error 0.035
# 	step 18000: train loss 0.189188, train error 0.00999999
# 	step 18200: train loss 0.188047, train error 0.0225
# 	step 18400: train loss 0.264195, train error 0.0575
# 	step 18600: train loss 0.294443, train error 0.0725
# 	step 18800: train loss 0.218089, train error 0.0275
# 	step 19000: train loss 0.185895, train error 0.00749999
# 	step 19200: train loss 0.205312, train error 0.0325
# 	step 19400: train loss 0.211554, train error 0.0225
# 	step 19600: train loss 0.191364, train error 0.02
# 	step 19800: train loss 0.169958, train error 0.0125
# 	step 20000: train loss 0.176111, train error 0.015
# 	step 20200: train loss 0.214928, train error 0.035
# 	step 20400: train loss 0.183898, train error 0.0125
# 	step 20600: train loss 0.191645, train error 0.02
# 	step 20800: train loss 0.177557, train error 0.0175
# 	step 21000: train loss 0.173913, train error 0.0125
# 	step 21200: train loss 0.177097, train error 0.00749999
# 	step 21400: train loss 0.163147, train error 0.00749999
# 	step 21600: train loss 0.191094, train error 0.0275
# 	step 21800: train loss 0.186976, train error 0.015
# 	step 22000: train loss 0.2034, train error 0.0275
# 	step 22200: train loss 0.183265, train error 0.015
# 	step 22400: train loss 0.197551, train error 0.0225
# 	step 22600: train loss 0.177881, train error 0.0125
# 	step 22800: train loss 0.157053, train error 0.00999999
# 	step 23000: train loss 0.160259, train error 0.005
# 	step 23200: train loss 0.150209, train error 0.005
# 	step 23400: train loss 0.149906, train error 0
# 	step 23600: train loss 0.189809, train error 0.0125
# 	step 23800: train loss 0.175668, train error 0.0125
# 	step 24000: train loss 0.178003, train error 0.015
# 	step 24200: train loss 0.161593, train error 0.00999999
# 	step 24400: train loss 0.18776, train error 0.015
# 	step 24600: train loss 0.164179, train error 0.00749999
# 	step 24800: train loss 0.175101, train error 0.025
# 	step 25000: train loss 0.168549, train error 0.0125
# 	step 25200: train loss 0.156688, train error 0.005
# 	step 25400: train loss 0.176497, train error 0.02
# 	step 25600: train loss 0.154143, train error 0.005
# 	step 25800: train loss 0.157018, train error 0.0025
# 	step 26000: train loss 0.175055, train error 0.0175
# 	step 26200: train loss 0.157012, train error 0.005
# 	step 26400: train loss 0.160263, train error 0.0025
# 	step 26600: train loss 0.150261, train error 0
# 	step 26800: train loss 0.157288, train error 0.0025
# 	step 27000: train loss 0.159263, train error 0.00999999
# 	step 27200: train loss 0.154005, train error 0.00749999
# 	step 27400: train loss 0.160145, train error 0
# 	step 27600: train loss 0.191125, train error 0.025
# 	step 27800: train loss 0.160352, train error 0.0025
# 	step 28000: train loss 0.162349, train error 0.005
# 	step 28200: train loss 0.15716, train error 0.0125
# 	step 28400: train loss 0.164204, train error 0.015
# 	step 28600: train loss 0.147491, train error 0.0025
# 	step 28800: train loss 0.147144, train error 0.0025
# 	step 29000: train loss 0.156479, train error 0.00749999
# 	step 29200: train loss 0.149768, train error 0.005
# 	step 29400: train loss 0.151959, train error 0.005
# 	step 29600: train loss 0.155149, train error 0.00749999
# 	step 29800: train loss 0.150262, train error 0.0025
# 	step 30000: train loss 0.184002, train error 0.0175
# 	step 30200: train loss 0.14759, train error 0.00749999
# 	step 30400: train loss 0.162764, train error 0.0025
# 	step 30600: train loss 0.180243, train error 0.0125
# 	step 30800: train loss 0.155349, train error 0.00749999
# 	step 31000: train loss 0.1477, train error 0.005
# 	step 31200: train loss 0.152184, train error 0.0025
# 	step 31400: train loss 0.139872, train error 0.005
# 	step 31600: train loss 0.139996, train error 0.005
# 	step 31800: train loss 0.163694, train error 0.0025
# 	step 32000: train loss 0.141605, train error 0.0025
# 	step 32200: train loss 0.147572, train error 0
# 	step 32400: train loss 0.146521, train error 0
# 	step 32600: train loss 0.155903, train error 0.005
# 	step 32800: train loss 0.157596, train error 0.005
# 	step 33000: train loss 0.14943, train error 0.0025
# 	step 33200: train loss 0.145555, train error 0.005
# 	step 33400: train loss 0.153343, train error 0
# 	step 33600: train loss 0.155372, train error 0.00749999
# 	step 33800: train loss 0.159413, train error 0.0125
# 	step 34000: train loss 0.153425, train error 0.0025
# 	step 34200: train loss 0.139059, train error 0
# 	step 34400: train loss 0.150118, train error 0.0025
# 	step 34600: train loss 0.153259, train error 0.0025
# 	step 34800: train loss 0.140186, train error 0
# 	step 35000: train loss 0.154608, train error 0.005
# 	step 35200: train loss 0.143864, train error 0
# 	step 35400: train loss 0.155367, train error 0.005
# 	step 35600: train loss 0.136507, train error 0
# 	step 35800: train loss 0.143626, train error 0.0025
# 	step 36000: train loss 0.136835, train error 0
# 	step 36200: train loss 0.145139, train error 0.0025
# 	step 36400: train loss 0.162098, train error 0.0125
# 	step 36600: train loss 0.141605, train error 0.0025
# 	step 36800: train loss 0.151679, train error 0.005
# 	step 37000: train loss 0.157005, train error 0.00749999
# 	step 37200: train loss 0.141905, train error 0
# 	step 37400: train loss 0.159516, train error 0.00999999
# 	step 37600: train loss 0.152103, train error 0.00749999
# 	step 37800: train loss 0.142602, train error 0.005
# 	step 38000: train loss 0.143535, train error 0.0025
# 	step 38200: train loss 0.153418, train error 0.005
# 	step 38400: train loss 0.151435, train error 0.005
# 	step 38600: train loss 0.146863, train error 0.005
# 	step 38800: train loss 0.14267, train error 0
# 	step 39000: train loss 0.141856, train error 0.0025
# 	step 39200: train loss 0.13971, train error 0.005
# 	step 39400: train loss 0.13778, train error 0
# 	step 39600: train loss 0.136781, train error 0.0025
# 	step 39800: train loss 0.160951, train error 0.015
# end training features // time elapsed: 5631.0115 s
# validation set error: 0.1542 // time elapsed: 1.4768 s

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNLarge0, settings=Baseline_Settings,
                                num_features=10, data_format=[32, 32, 3],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gl0_cifar10_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gl0_cifar10_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.7, f_params=f_params)
    fs.save(sess, "./models/cifar10/b_gl0_cifar10_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.79397, train error 0.885
# 	step 200: train loss 3.74415, train error 0.85
# 	step 400: train loss 2.22412, train error 0.635
# 	step 600: train loss 2.27793, train error 0.6075
# 	step 800: train loss 1.47537, train error 0.4
# 	step 1000: train loss 1.75872, train error 0.475
# 	step 1200: train loss 1.44358, train error 0.4
# 	step 1400: train loss 1.21639, train error 0.3175
# 	step 1600: train loss 1.2604, train error 0.3325
# 	step 1800: train loss 1.14973, train error 0.2975
# 	step 2000: train loss 1.09639, train error 0.3225
# 	step 2200: train loss 1.22864, train error 0.3275
# 	step 2400: train loss 0.950521, train error 0.225
# 	step 2600: train loss 0.848048, train error 0.215
# 	step 2800: train loss 0.810717, train error 0.1775
# 	step 3000: train loss 0.89202, train error 0.245
# 	step 3200: train loss 0.735706, train error 0.155
# 	step 3400: train loss 1.22048, train error 0.3325
# 	step 3600: train loss 0.724135, train error 0.1825
# 	step 3800: train loss 0.641952, train error 0.16
# 	step 4000: train loss 0.679103, train error 0.165
# 	step 4200: train loss 0.638906, train error 0.16
# 	step 4400: train loss 0.659823, train error 0.1575
# 	step 4600: train loss 0.504435, train error 0.1075
# 	step 4800: train loss 0.573861, train error 0.145
# 	step 5000: train loss 0.640278, train error 0.18
# 	step 5200: train loss 0.649817, train error 0.1825
# 	step 5400: train loss 0.422332, train error 0.0875
# 	step 5600: train loss 0.467948, train error 0.095
# 	step 5800: train loss 0.50751, train error 0.1225
# 	step 6000: train loss 0.442821, train error 0.105
# 	step 6200: train loss 0.375246, train error 0.0675
# 	step 6400: train loss 0.434729, train error 0.095
# 	step 6600: train loss 0.45381, train error 0.1325
# 	step 6800: train loss 0.349821, train error 0.0575
# 	step 7000: train loss 0.458378, train error 0.0975
# 	step 7200: train loss 0.336016, train error 0.05
# 	step 7400: train loss 0.376938, train error 0.0875
# 	step 7600: train loss 0.361969, train error 0.0775
# 	step 7800: train loss 0.259199, train error 0.0425
# 	step 8000: train loss 0.359147, train error 0.075
# 	step 8200: train loss 0.337191, train error 0.0675
# 	step 8400: train loss 0.32962, train error 0.08
# 	step 8600: train loss 0.256002, train error 0.0325
# 	step 8800: train loss 0.313693, train error 0.0625
# 	step 9000: train loss 0.298808, train error 0.065
# 	step 9200: train loss 0.262586, train error 0.04
# 	step 9400: train loss 0.269995, train error 0.045
# 	step 9600: train loss 0.25221, train error 0.04
# 	step 9800: train loss 0.232202, train error 0.03
# 	step 10000: train loss 0.22899, train error 0.0325
# 	step 10200: train loss 0.207799, train error 0.02
# 	step 10400: train loss 0.241696, train error 0.03
# 	step 10600: train loss 0.199614, train error 0.0125
# 	step 10800: train loss 0.216462, train error 0.025
# 	step 11000: train loss 0.245162, train error 0.0375
# 	step 11200: train loss 0.211876, train error 0.0275
# 	step 11400: train loss 0.195105, train error 0.02
# 	step 11600: train loss 0.198601, train error 0.02
# 	step 11800: train loss 0.18386, train error 0.00999999
# 	step 12000: train loss 0.195648, train error 0.0125
# 	step 12200: train loss 0.203319, train error 0.0175
# 	step 12400: train loss 0.177359, train error 0.00749999
# 	step 12600: train loss 0.320491, train error 0.0575
# 	step 12800: train loss 0.194659, train error 0.015
# 	step 13000: train loss 0.193301, train error 0.025
# 	step 13200: train loss 0.162145, train error 0.005
# 	step 13400: train loss 0.155774, train error 0.0025
# 	step 13600: train loss 0.165879, train error 0.005
# 	step 13800: train loss 0.257084, train error 0.0375
# 	step 14000: train loss 0.155646, train error 0.0025
# 	step 14200: train loss 0.191852, train error 0.0125
# 	step 14400: train loss 0.16409, train error 0.00749999
# 	step 14600: train loss 0.161702, train error 0
# 	step 14800: train loss 0.1801, train error 0.00999999
# 	step 15000: train loss 0.195785, train error 0.0175
# 	step 15200: train loss 0.174668, train error 0.005
# 	step 15400: train loss 0.157784, train error 0.0025
# 	step 15600: train loss 0.150638, train error 0
# 	step 15800: train loss 0.150918, train error 0
# 	step 16000: train loss 0.155353, train error 0.0025
# 	step 16200: train loss 0.161496, train error 0
# 	step 16400: train loss 0.154034, train error 0.0025
# 	step 16600: train loss 0.147554, train error 0
# 	step 16800: train loss 0.175206, train error 0.00749999
# 	step 17000: train loss 0.152101, train error 0.0025
# 	step 17200: train loss 0.186954, train error 0.00749999
# 	step 17400: train loss 0.153259, train error 0.0025
# 	step 17600: train loss 0.154604, train error 0.0025
# 	step 17800: train loss 0.150792, train error 0
# 	step 18000: train loss 0.155602, train error 0.005
# 	step 18200: train loss 0.173912, train error 0.00749999
# 	step 18400: train loss 0.158563, train error 0
# 	step 18600: train loss 0.155925, train error 0
# 	step 18800: train loss 0.151721, train error 0
# 	step 19000: train loss 0.149876, train error 0.0025
# 	step 19200: train loss 0.163701, train error 0.00749999
# 	step 19400: train loss 0.149085, train error 0
# 	step 19600: train loss 0.152869, train error 0
# 	step 19800: train loss 0.160581, train error 0
# 	step 20000: train loss 0.148643, train error 0
# 	step 20200: train loss 0.155294, train error 0.0025
# 	step 20400: train loss 0.147861, train error 0
# 	step 20600: train loss 0.148265, train error 0
# 	step 20800: train loss 0.152545, train error 0
# 	step 21000: train loss 0.149521, train error 0
# 	step 21200: train loss 0.148068, train error 0
# 	step 21400: train loss 0.171864, train error 0.0025
# 	step 21600: train loss 0.1594, train error 0.0025
# 	step 21800: train loss 0.155287, train error 0.0025
# 	step 22000: train loss 0.150725, train error 0
# 	step 22200: train loss 0.145628, train error 0
# 	step 22400: train loss 0.16281, train error 0.005
# 	step 22600: train loss 0.150078, train error 0
# 	step 22800: train loss 0.148863, train error 0
# 	step 23000: train loss 0.149978, train error 0
# 	step 23200: train loss 0.154392, train error 0
# 	step 23400: train loss 0.14755, train error 0
# 	step 23600: train loss 0.148403, train error 0
# 	step 23800: train loss 0.149093, train error 0
# 	step 24000: train loss 0.153293, train error 0
# 	step 24200: train loss 0.154172, train error 0.0025
# 	step 24400: train loss 0.151202, train error 0.0025
# 	step 24600: train loss 0.160924, train error 0.0025
# 	step 24800: train loss 0.149851, train error 0
# 	step 25000: train loss 0.148132, train error 0
# 	step 25200: train loss 0.150242, train error 0
# 	step 25400: train loss 0.154535, train error 0.0025
# 	step 25600: train loss 0.147092, train error 0
# 	step 25800: train loss 0.147511, train error 0
# 	step 26000: train loss 0.149874, train error 0
# 	step 26200: train loss 0.146078, train error 0
# 	step 26400: train loss 0.149635, train error 0
# 	step 26600: train loss 0.146631, train error 0
# 	step 26800: train loss 0.155833, train error 0.005
# 	step 27000: train loss 0.154672, train error 0
# 	step 27200: train loss 0.149043, train error 0
# 	step 27400: train loss 0.164824, train error 0.00749999
# 	step 27600: train loss 0.149099, train error 0
# 	step 27800: train loss 0.152053, train error 0
# 	step 28000: train loss 0.149877, train error 0
# 	step 28200: train loss 0.149415, train error 0.0025
# 	step 28400: train loss 0.147065, train error 0
# 	step 28600: train loss 0.148093, train error 0
# 	step 28800: train loss 0.147817, train error 0
# 	step 29000: train loss 0.14794, train error 0
# 	step 29200: train loss 0.147982, train error 0.0025
# 	step 29400: train loss 0.149018, train error 0
# 	step 29600: train loss 0.146869, train error 0
# 	step 29800: train loss 0.146224, train error 0
# 	step 30000: train loss 0.149103, train error 0.0025
# 	step 30200: train loss 0.146933, train error 0
# 	step 30400: train loss 0.14601, train error 0
# 	step 30600: train loss 0.145958, train error 0
# 	step 30800: train loss 0.145319, train error 0
# 	step 31000: train loss 0.149262, train error 0
# 	step 31200: train loss 0.150014, train error 0
# 	step 31400: train loss 0.145373, train error 0
# 	step 31600: train loss 0.14707, train error 0
# 	step 31800: train loss 0.148914, train error 0.0025
# 	step 32000: train loss 0.145656, train error 0
# 	step 32200: train loss 0.147947, train error 0
# 	step 32400: train loss 0.14714, train error 0
# 	step 32600: train loss 0.147488, train error 0
# 	step 32800: train loss 0.146327, train error 0
# 	step 33000: train loss 0.145557, train error 0
# 	step 33200: train loss 0.145228, train error 0
# 	step 33400: train loss 0.145815, train error 0
# 	step 33600: train loss 0.146857, train error 0
# 	step 33800: train loss 0.14548, train error 0
# 	step 34000: train loss 0.146166, train error 0
# 	step 34200: train loss 0.145577, train error 0
# 	step 34400: train loss 0.146502, train error 0
# 	step 34600: train loss 0.145345, train error 0
# 	step 34800: train loss 0.146695, train error 0
# 	step 35000: train loss 0.144698, train error 0
# 	step 35200: train loss 0.144963, train error 0
# 	step 35400: train loss 0.145031, train error 0
# 	step 35600: train loss 0.144379, train error 0
# 	step 35800: train loss 0.148066, train error 0.0025
# 	step 36000: train loss 0.145379, train error 0
# 	step 36200: train loss 0.15235, train error 0.005
# 	step 36400: train loss 0.145187, train error 0
# 	step 36600: train loss 0.146181, train error 0
# 	step 36800: train loss 0.144223, train error 0
# 	step 37000: train loss 0.143518, train error 0
# 	step 37200: train loss 0.142932, train error 0
# 	step 37400: train loss 0.145408, train error 0
# 	step 37600: train loss 0.145375, train error 0
# 	step 37800: train loss 0.149108, train error 0.0025
# 	step 38000: train loss 0.143126, train error 0
# 	step 38200: train loss 0.144623, train error 0
# 	step 38400: train loss 0.143198, train error 0
# 	step 38600: train loss 0.143403, train error 0
# 	step 38800: train loss 0.142803, train error 0
# 	step 39000: train loss 0.14279, train error 0
# 	step 39200: train loss 0.143275, train error 0
# 	step 39400: train loss 0.142506, train error 0
# 	step 39600: train loss 0.143812, train error 0
# 	step 39800: train loss 0.14244, train error 0
# end training features // time elapsed: 7138.0406 s
# validation set error: 0.1226 // time elapsed: 1.2859 s
