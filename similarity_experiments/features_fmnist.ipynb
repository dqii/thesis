# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
from features.settings import Baseline_Settings, Triplet_Hinge_Settings, Triplet_Log_Settings, Pair_Hinge_Settings
from features.models import CNNSmall0, CNNSmall1, CNNSmall2, CNNMedium0, CNNMedium1, CNNLarge0, CNNLarge1
from features.models import STNCNNSmall0, STNCNNSmall1, STNCNNSmall2, STNCNNMedium0, STNCNNMedium1
from features.models import GCNNSmall0, GCNNMedium0, GCNNMedium1, GCNNLarge0
from learn import get_feature_model, train_features, test_features
from datasets import load_fashion_mnist
# Out:
# /home/dqi/.conda/envs/py36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/dqi/.conda/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data, samplers, pair_samplers, triplet_samplers = load_fashion_mnist(augment=True)
# Out:
# Fashion MNIST loaded in 37 seconds

# %% [markdown]
# # Triplets

# %%
d = data; s=triplet_samplers

# %%
# 0.0296
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_cs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/f_cs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04985, train error 0.49, valid loss 1.04879, valid error 0.461429
# 	step 200: train loss 0.970408, train error 0.387143, valid loss 0.91151, valid error 0.304286
# 	step 400: train loss 0.480637, train error 0.16, valid loss 0.358045, valid error 0.117143
# 	step 600: train loss 0.300141, train error 0.101429, valid loss 0.236582, valid error 0.08
# 	step 800: train loss 0.261054, train error 0.0842857, valid loss 0.217669, valid error 0.0757143
# 	step 1000: train loss 0.287762, train error 0.124286, valid loss 0.180538, valid error 0.0528572
# 	step 1200: train loss 0.201785, train error 0.0557143, valid loss 0.207615, valid error 0.0642857
# 	step 1400: train loss 0.188432, train error 0.06, valid loss 0.215328, valid error 0.0714286
# 	step 1600: train loss 0.205743, train error 0.0757143, valid loss 0.188974, valid error 0.0557143
# 	step 1800: train loss 0.226683, train error 0.0842857, valid loss 0.176242, valid error 0.0585715
# ...

# %%
# 0.0242
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_cs1_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_cs1_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/f_cs1_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04403, train error 0.505714, valid loss 1.02456, valid error 0.441429
# 	step 200: train loss 1.0186, train error 0.42, valid loss 0.983011, valid error 0.331429
# 	step 400: train loss 0.563171, train error 0.195714, valid loss 0.495759, valid error 0.17
# 	step 600: train loss 0.308059, train error 0.1, valid loss 0.236736, valid error 0.0785714
# 	step 800: train loss 0.279407, train error 0.0942857, valid loss 0.213849, valid error 0.0728571
# 	step 1000: train loss 0.23503, train error 0.0771428, valid loss 0.181992, valid error 0.0571429
# 	step 1200: train loss 0.251658, train error 0.0857143, valid loss 0.225152, valid error 0.0814286
# 	step 1400: train loss 0.214155, train error 0.07, valid loss 0.223945, valid error 0.0757143
# 	step 1600: train loss 0.223579, train error 0.0828571, valid loss 0.178649, valid error 0.0614285
# 	step 1800: train loss 0.205122, train error 0.0742857, valid loss 0.201084, valid error 0.0742857
# ...

# %%
# 0.0556
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=STNCNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="f_scs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_scs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/f_scs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.04924, train error 0.482857, valid loss 1.0499, valid error 0.498571
# 	step 200: train loss 0.763974, train error 0.254286, valid loss 0.711098, valid error 0.178571
# 	step 400: train loss 0.491717, train error 0.162857, valid loss 0.449664, valid error 0.15
# 	step 600: train loss 0.437373, train error 0.177143, valid loss 0.37402, valid error 0.132857
# 	step 800: train loss 0.39277, train error 0.142857, valid loss 0.287692, valid error 0.0971429
# 	step 1000: train loss 0.403504, train error 0.155714, valid loss 0.294564, valid error 0.111429
# 	step 1200: train loss 0.355341, train error 0.12, valid loss 0.292527, valid error 0.0985714
# 	step 1400: train loss 0.316979, train error 0.104286, valid loss 0.300874, valid error 0.112857
# 	step 1600: train loss 0.32729, train error 0.121429, valid loss 0.277291, valid error 0.104286
# 	step 1800: train loss 0.336389, train error 0.135714, valid loss 0.255733, valid error 0.0957143
# ...

# %%
# 0.0182
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="f_gs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_gs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=60000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/f_gs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 1.44512, train error 0.427143, valid loss 1.44371, valid error 0.395714
# 	step 200: train loss 1.13412, train error 0.228571, valid loss 1.04399, valid error 0.197143
# 	step 400: train loss 0.790654, train error 0.158571, valid loss 0.684829, valid error 0.09
# 	step 600: train loss 0.558068, train error 0.0671428, valid loss 0.535422, valid error 0.0585715
# 	step 800: train loss 0.537633, train error 0.0628572, valid loss 0.516379, valid error 0.0585715
# 	step 1000: train loss 0.489087, train error 0.0514286, valid loss 0.519048, valid error 0.06
# 	step 1200: train loss 0.472996, train error 0.0485714, valid loss 0.441961, valid error 0.0357143
# 	step 1400: train loss 0.454809, train error 0.0457143, valid loss 0.426953, valid error 0.0471429
# 	step 1600: train loss 0.436354, train error 0.0471429, valid loss 0.434523, valid error 0.0514286
# ...

# %% [markdown]
# # Baseline

# %%
d=data; s=samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="b_cs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/b_cs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.42825, train error 0.931429, valid loss 2.44064, valid error 0.944286
# 	step 200: train loss 3.11449, train error 0.822857, valid loss 2.92884, valid error 0.784286
# 	step 400: train loss 2.14949, train error 0.691429, valid loss 1.77542, valid error 0.634286
# 	step 600: train loss 0.806191, train error 0.281429, valid loss 0.661541, valid error 0.231429
# 	step 800: train loss 0.682827, train error 0.208571, valid loss 0.545644, valid error 0.18
# 	step 1000: train loss 0.626553, train error 0.228571, valid loss 0.552757, valid error 0.187143
# 	step 1200: train loss 0.625103, train error 0.225714, valid loss 0.483822, valid error 0.181429
# 	step 1400: train loss 0.586423, train error 0.195714, valid loss 0.491877, valid error 0.18
# 	step 1600: train loss 0.558358, train error 0.19, valid loss 0.495428, valid error 0.182857
# 	step 1800: train loss 0.514345, train error 0.182857, valid loss 0.458063, valid error 0.154286
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="b_cs1_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_cs1_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/b_cs1_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.39109, train error 0.911429, valid loss 2.39799, valid error 0.9
# 	step 200: train loss 4.60609, train error 0.874286, valid loss 4.26679, valid error 0.85
# 	step 400: train loss 2.85223, train error 0.702857, valid loss 2.79162, valid error 0.632857
# 	step 600: train loss 0.853151, train error 0.291429, valid loss 0.703572, valid error 0.254286
# 	step 800: train loss 0.596537, train error 0.204286, valid loss 0.532325, valid error 0.178571
# 	step 1000: train loss 0.611621, train error 0.235714, valid loss 0.488767, valid error 0.182857
# 	step 1200: train loss 0.593067, train error 0.22, valid loss 0.489109, valid error 0.165714
# 	step 1400: train loss 0.591172, train error 0.217143, valid loss 0.524301, valid error 0.18
# 	step 1600: train loss 0.650932, train error 0.248571, valid loss 0.566949, valid error 0.201429
# 	step 1800: train loss 0.659735, train error 0.262857, valid loss 0.506853, valid error 0.174286
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/b_gs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.73902, train error 0.772857, valid loss 2.71983, valid error 0.715714
# 	step 200: train loss 4.16471, train error 0.795714, valid loss 4.11336, valid error 0.788571
# 	step 400: train loss 3.22401, train error 0.692857, valid loss 2.75399, valid error 0.612857
# 	step 600: train loss 0.887014, train error 0.184286, valid loss 0.750774, valid error 0.13
# 	step 800: train loss 0.722201, train error 0.11, valid loss 0.680581, valid error 0.114286
# 	step 1000: train loss 0.729816, train error 0.151429, valid loss 0.68114, valid error 0.107143
# 	step 1200: train loss 0.682101, train error 0.121429, valid loss 0.625991, valid error 0.101429
# 	step 1400: train loss 0.67001, train error 0.111429, valid loss 0.542916, valid error 0.05
# 	step 1600: train loss 0.582828, train error 0.0914286, valid loss 0.596443, valid error 0.11
# 	step 1800: train loss 0.629372, train error 0.105714, valid loss 0.500604, valid error 0.08
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="b_gs0_fmnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "b_gs0_fmnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=40000, keep_prob=0.5, f_params=f_params)
    fs.save(sess, "./models/fmnist/b_gs0_fmnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.77666, train error 0.885714, valid loss 2.77773, valid error 0.904286
# 	step 200: train loss 3.79, train error 0.778571, valid loss 3.5209, valid error 0.744286
# 	step 400: train loss 2.39048, train error 0.642857, valid loss 1.97043, valid error 0.56
# 	step 600: train loss 1.10378, train error 0.274286, valid loss 0.993656, valid error 0.252857
# 	step 800: train loss 1.00312, train error 0.251429, valid loss 0.989508, valid error 0.252857
# 	step 1000: train loss 1.07162, train error 0.265714, valid loss 0.874925, valid error 0.16
# 	step 1200: train loss 0.946561, train error 0.251429, valid loss 0.832039, valid error 0.19
# 	step 1400: train loss 0.964184, train error 0.23, valid loss 0.802469, valid error 0.187143
# 	step 1600: train loss 0.868997, train error 0.208571, valid loss 0.780155, valid error 0.188571
# 	step 1800: train loss 0.81944, train error 0.202857, valid loss 0.762804, valid error 0.17
# ...

# %% [markdown]
# # Small Baseline

# %%
d=data; s=samplers

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="sb_cs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_cs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.37814, train error 0.892857, valid loss 2.37706, valid error 0.895714
# 	step 200: train loss 3.96027, train error 0.877143, valid loss 3.54205, valid error 0.838571
# 	step 400: train loss 2.73283, train error 0.68, valid loss 2.43335, valid error 0.61
# 	step 600: train loss 0.745083, train error 0.2575, valid loss 0.662224, valid error 0.222857
# 	step 800: train loss 0.649287, train error 0.241429, valid loss 0.542566, valid error 0.171429
# 	step 1000: train loss 0.5765, train error 0.2, valid loss 0.495187, valid error 0.158571
# 	step 1200: train loss 0.537023, train error 0.172857, valid loss 0.500833, valid error 0.165714
# 	step 1400: train loss 0.491251, train error 0.177143, valid loss 0.506131, valid error 0.178571
# 	step 1600: train loss 0.552869, train error 0.197143, valid loss 0.556606, valid error 0.187143
# 	step 1800: train loss 0.49263, train error 0.18, valid loss 0.428847, valid error 0.137143
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=CNNSmall1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.05, f_reg=0.001, f_scope="sb_cs1_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_cs1_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_cs1_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.45527, train error 0.871429, valid loss 2.45825, valid error 0.877143
# 	step 200: train loss 3.19973, train error 0.804286, valid loss 3.38608, valid error 0.828571
# 	step 400: train loss 3.01982, train error 0.751429, valid loss 2.90412, valid error 0.73
# 	step 600: train loss 0.820884, train error 0.307143, valid loss 0.763419, valid error 0.265714
# 	step 800: train loss 0.631017, train error 0.221429, valid loss 0.546017, valid error 0.178571
# 	step 1000: train loss 0.554976, train error 0.191429, valid loss 0.502402, valid error 0.155714
# 	step 1200: train loss 0.513596, train error 0.167143, valid loss 0.442428, valid error 0.144286
# 	step 1400: train loss 0.544715, train error 0.182857, valid loss 0.397387, valid error 0.12
# 	step 1600: train loss 0.533399, train error 0.188571, valid loss 0.439869, valid error 0.16
# 	step 1800: train loss 0.468735, train error 0.167143, valid loss 0.430797, valid error 0.138571
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_gs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.8, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gs0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.74215, train error 0.891429, valid loss 2.76541, valid error 0.877143
# 	step 200: train loss 3.38457, train error 0.762857, valid loss 3.25973, valid error 0.711429
# 	step 400: train loss 2.06494, train error 0.56, valid loss 1.81382, valid error 0.488571
# 	step 600: train loss 0.843548, train error 0.168571, valid loss 0.775434, valid error 0.135714
# 	step 800: train loss 0.676096, train error 0.0928571, valid loss 0.716621, valid error 0.13
# 	step 1000: train loss 0.664594, train error 0.11, valid loss 0.750059, valid error 0.154286
# 	step 1200: train loss 0.504356, train error 0.05, valid loss 0.689013, valid error 0.131429
# 	step 1400: train loss 0.52649, train error 0.0671428, valid loss 0.656562, valid error 0.1
# 	step 1600: train loss 0.474136, train error 0.0571429, valid loss 0.639389, valid error 0.111429
# 	step 1800: train loss 0.41989, train error 0.0342857, valid loss 0.585295, valid error 0.0971429
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_gs0_fmnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gs0_fmnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.6, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gs0_fmnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.77674, train error 0.907143, valid loss 2.75363, valid error 0.904286
# 	step 200: train loss 3.63716, train error 0.788571, valid loss 3.3415, valid error 0.725714
# 	step 400: train loss 2.30209, train error 0.592857, valid loss 1.99441, valid error 0.531429
# 	step 600: train loss 1.00744, train error 0.215714, valid loss 0.902636, valid error 0.207143
# 	step 800: train loss 0.907511, train error 0.2, valid loss 0.777656, valid error 0.141429
# 	step 1000: train loss 0.907161, train error 0.214286, valid loss 0.807456, valid error 0.185714
# 	step 1200: train loss 0.808486, train error 0.181429, valid loss 0.790766, valid error 0.154286
# 	step 1400: train loss 0.782114, train error 0.165714, valid loss 0.886028, valid error 0.21
# 	step 1600: train loss 0.719377, train error 0.151429, valid loss 0.660331, valid error 0.134286
# 	step 1800: train loss 0.688382, train error 0.135714, valid loss 0.683412, valid error 0.154286
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_gs0_fmnist_10-")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gs0_fmnist_10-"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.5, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gs0_fmnist_10-.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.84899, train error 0.914286, valid loss 2.85904, valid error 0.894286
# 	step 200: train loss 3.6512, train error 0.802857, valid loss 3.62503, valid error 0.781429
# 	step 400: train loss 2.24958, train error 0.615714, valid loss 1.90573, valid error 0.544286
# 	step 600: train loss 1.09565, train error 0.271429, valid loss 0.955638, valid error 0.22
# 	step 800: train loss 1.07137, train error 0.281429, valid loss 0.946125, valid error 0.228571
# 	step 1000: train loss 1.01702, train error 0.242857, valid loss 0.899539, valid error 0.222857
# 	step 1200: train loss 1.00242, train error 0.254286, valid loss 0.873168, valid error 0.212857
# 	step 1400: train loss 1.00473, train error 0.244286, valid loss 0.810828, valid error 0.14
# 	step 1600: train loss 0.866624, train error 0.218571, valid loss 0.786173, valid error 0.19
# 	step 1800: train loss 0.818813, train error 0.191429, valid loss 0.719234, valid error 0.161429
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNMedium0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_gm0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gm0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.6, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gm0_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 3.15639, train error 0.88, valid loss 3.15469, valid error 0.872857
# 	step 200: train loss 5.07273, train error 0.83, valid loss 4.67859, valid error 0.795714
# 	step 400: train loss 1.87015, train error 0.424286, valid loss 1.66848, valid error 0.362857
# 	step 600: train loss 1.3231, train error 0.21, valid loss 1.20662, valid error 0.185714
# 	step 800: train loss 1.19102, train error 0.182857, valid loss 1.09069, valid error 0.16
# 	step 1000: train loss 1.10214, train error 0.17, valid loss 1.05618, valid error 0.142857
# 	step 1200: train loss 1.0881, train error 0.172857, valid loss 1.01111, valid error 0.15
# 	step 1400: train loss 0.975996, train error 0.145714, valid loss 0.914385, valid error 0.14
# 	step 1600: train loss 0.916702, train error 0.124286, valid loss 0.937039, valid error 0.151429
# 	step 1800: train loss 0.910326, train error 0.151429, valid loss 0.892733, valid error 0.132857
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNMedium0, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="sb_gm0_fmnist_10_")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gm0_fmnist_10_"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.5, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gm0_fmnist_10_.ckpt")
# Out:
# begin training features
# 	step 0: train loss 3.14665, train error 0.841429, valid loss 3.14239, valid error 0.804286
# 	step 200: train loss 4.51442, train error 0.788571, valid loss 4.37704, valid error 0.721429
# 	step 400: train loss 3.23657, train error 0.692857, valid loss 2.86518, valid error 0.632857
# 	step 600: train loss 1.3931, train error 0.265714, valid loss 1.27867, valid error 0.228571
# 	step 800: train loss 1.25965, train error 0.205714, valid loss 1.21068, valid error 0.204286
# 	step 1000: train loss 1.18602, train error 0.2, valid loss 1.12589, valid error 0.212857
# 	step 1200: train loss 1.09675, train error 0.1875, valid loss 1.1264, valid error 0.21
# 	step 1400: train loss 1.11288, train error 0.2, valid loss 1.06199, valid error 0.18
# 	step 1600: train loss 1.00685, train error 0.181429, valid loss 0.965373, valid error 0.16
# 	step 1800: train loss 1.02108, train error 0.175714, valid loss 0.912775, valid error 0.141429
# ...

# %%
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNMedium1, settings=Baseline_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.02, f_reg=0.001, f_scope="sb_gm1_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "sb_gm1_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_features(sess=sess, feature_model=f, samplers=s, num_steps=20000, keep_prob=0.5, f_params=f_params)
    fs.save(sess, "./models/fmnist/sb_gm1_fmnist_10.ckpt")
# Out:
# begin training features
# 	step 0: train loss 2.82239, train error 0.93, valid loss 2.7812, valid error 0.905714
# 	step 200: train loss 6.37286, train error 0.875714, valid loss 6.14496, valid error 0.878571
# 	step 400: train loss 4.32685, train error 0.848571, valid loss 4.29333, valid error 0.814286
# 	step 600: train loss 1.29338, train error 0.358571, valid loss 1.12976, valid error 0.261429
# 	step 800: train loss 1.10702, train error 0.302857, valid loss 0.982062, valid error 0.215714
# 	step 1000: train loss 1.05184, train error 0.251429, valid loss 1.02987, valid error 0.257143
# 	step 1200: train loss 1.07025, train error 0.287143, valid loss 0.999738, valid error 0.252857
# 	step 1400: train loss 1.10538, train error 0.291429, valid loss 0.945315, valid error 0.27
# 	step 1600: train loss 0.979798, train error 0.254286, valid loss 0.958707, valid error 0.227143
# 	step 1800: train loss 0.938254, train error 0.232857, valid loss 0.876438, valid error 0.198571
# ...

# %% [markdown]
# # Test

# %%
d = data; s=triplet_samplers

# %%
# 0.0182
tf.reset_default_graph()
f, f_params = get_feature_model(feature_model=GCNNSmall0, settings=Triplet_Hinge_Settings,
                                num_features=10, data_format=[28, 28, 1],
                                f_lr=0.04, f_reg=0.001, f_scope="f_gs0_fmnist_10")
fs = tf.train.Saver(tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, "f_gs0_fmnist_10"))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    fs.restore(sess, "./models/fmnist/f_gs0_fmnist_10.ckpt")
    test_features(sess=sess, feature_model=f, samplers=s, f_params=f_params)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/f_gs0_fmnist_10.ckpt
# test set error: 0.0159 // time elapsed: 41.1011 s
